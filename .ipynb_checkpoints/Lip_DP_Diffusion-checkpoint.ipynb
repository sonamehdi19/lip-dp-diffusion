# %% [markdown]
# # Lip-DP-Diffusion Implementation

# %%
# !pip install -q opacus torch-fidelity

# %%
import torch
print(torch.cuda.device_count())      # 1
print(torch.cuda.current_device())    # 0
print(torch.cuda.get_device_name(0))  # NVIDIA A100-SXM4-40GB
# Out:
# 1
# 0
# NVIDIA A100-SXM4-40GB

# %%
import os, math, json, random
from datetime import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torchvision.utils import save_image, make_grid
from torch.utils.data import DataLoader

from opacus.accountants import RDPAccountant
from opacus.utils.uniform_sampler import UniformWithReplacementSampler
from torch_fidelity import calculate_metrics
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Out:
# device: cuda
# RUN_DIR: ./diffusion_experiments/29.01.2026

# %%
def seed_all(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_all(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

torch.backends.cudnn.benchmark = True

# %%
try:
    from google.colab import drive
    drive.mount("/content/drive")
    BASE_DRIVE_DIR = "/content/drive/MyDrive/diffusion_experiments"
except Exception:
    BASE_DRIVE_DIR = "./diffusion_experiments"

DATE_STR = datetime.now().strftime("%d.%m.%Y")
RUN_DIR = os.path.join(BASE_DRIVE_DIR, DATE_STR)
os.makedirs(RUN_DIR, exist_ok=True)
print("RUN_DIR:", RUN_DIR)

def make_exp_dir(exp_name: str):
    exp_dir = os.path.join(RUN_DIR, exp_name)
    os.makedirs(exp_dir, exist_ok=True)
    for sub in ["checkpoints", "samples", "metrics", "fid_is", "synthetic_data", "diagnostics"]:
        os.makedirs(os.path.join(exp_dir, sub), exist_ok=True)
    return exp_dir

def save_json(obj, path):
    with open(path, "w") as f:
        json.dump(obj, f, indent=2)

# %% [markdown]
# ### Data Import

# %%
#  Data
train_tfm = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: (x * 2) - 1),
])
test_tfm = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: (x * 2) - 1),
])

mnist_train = MNIST(root="./data", train=True, transform=train_tfm, download=True)
mnist_test  = MNIST(root="./data", train=False, transform=test_tfm, download=True)

# %%
# public norm of X0
max_norm = 0.0
for x, _ in mnist_train:
    norm = torch.linalg.norm(x.view(-1))     # Flatten to (1, -1) to get vector norm per image
    if norm > max_norm:
        max_norm = norm

print(f"Computed max dataset norm: {max_norm}")
X0_PUBLIC = float(max_norm)
# Out:
# Computed max dataset norm: 28.0

# %% [markdown]
# ### Conditional U-Net

# %%
class LipSiLU(nn.Module):
    # conservative scaling: make SiLU ~ 1-Lipschitz
    def __init__(self, scale: float = 1/1.0998393):
        super().__init__()
        self.scale = float(scale)
    def forward(self, x):
        return self.scale * F.silu(x)

# %%
class LipschitzGroupNorm(nn.Module):
    """
    Conservative GroupNorm: denominator clamped >= 1 to be non-expansive.
    """
    def __init__(self, num_groups, num_channels):
        super().__init__()
        self.num_groups = num_groups
        self.num_channels = num_channels

    def forward(self, x):
        B, C, H, W = x.shape
        G = self.num_groups
        x = x.view(B, G, C // G, H, W)
        mean = x.mean(dim=[2, 3, 4], keepdim=True)
        var  = x.var(dim=[2, 3, 4], keepdim=True, unbiased=False)
        std  = (var + 1e-5).sqrt()
        denom = torch.clamp(std, min=1.0)
        x_norm = (x - mean) / denom
        return x_norm.view(B, C, H, W)

# %%
def get_time_embedding(time_steps, t_emb_dim, device):
    half_dim = t_emb_dim // 2
    emb = math.log(10000) / (half_dim - 1)
    emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
    emb = time_steps[:, None].float() * emb[None, :]
    emb = torch.cat([torch.sin(emb), torch.cos(emb)], dim=1)
    if t_emb_dim % 2 == 1:
        emb = F.pad(emb, (0, 1, 0, 0))
    return emb

# %%
class UpBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode="nearest")
        self.conv = nn.Conv2d(in_ch, out_ch, 3, padding=1)
    def forward(self, x):
        return self.conv(self.up(x))

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, t_emb_dim, use_lip_norm=True):
        super().__init__()
        self.act = LipSiLU() #if use_lip_norm else nn.SiLU()

        self.conv1 = nn.Conv2d(in_channels, out_channels, 3, padding=1)
        self.conv2 = nn.Conv2d(out_channels, out_channels, 3, padding=1)

        self.time_mlp = nn.Sequential(
            self.act,
            nn.Linear(t_emb_dim, out_channels * 2),
        )

        self.skip_conv = nn.Conv2d(in_channels, out_channels, 1) if in_channels != out_channels else nn.Identity()

        if use_lip_norm:
            self.gn1 = LipschitzGroupNorm(num_groups=8, num_channels=out_channels)
            self.gn2 = LipschitzGroupNorm(num_groups=8, num_channels=out_channels)
        else:
            self.gn1 = nn.GroupNorm(8, out_channels, affine=False)
            self.gn2 = nn.GroupNorm(8, out_channels, affine=False)

    def forward(self, x, emb):
        h = self.conv1(x)
        h = self.gn1(h)

        time_emb = self.time_mlp(emb).unsqueeze(-1).unsqueeze(-1)
        scale, shift = time_emb.chunk(2, dim=1)
        scale = (torch.tanh(scale)+1) /2 #  / 2    # ∈ (0,1), derivative=0.5 at init
        h = self.act(h * scale + shift)

        h = self.conv2(h)
        h = self.gn2(h)
        h = self.act(h)

        skip = self.skip_conv(x)
        return (h + skip) / math.sqrt(2.0)

# %%
class CondDiffUNet(nn.Module):
    def __init__(self, in_channels=1, base_channels=64, t_emb_dim=128, n_classes=11, use_lip_norm=True):
        super().__init__()
        self.t_emb_dim = t_emb_dim
        self.n_classes = n_classes

        self.label_emb = nn.Embedding(n_classes, t_emb_dim)
        act = LipSiLU() # if use_lip_norm else nn.SiLU()

        self.time_proj = nn.Sequential(
            nn.Linear(t_emb_dim, t_emb_dim),
            act,
            nn.Linear(t_emb_dim, t_emb_dim),
        )

        # Down
        self.down1 = ResBlock(in_channels, base_channels, t_emb_dim, use_lip_norm)
        self.pool1 = nn.Conv2d(base_channels, base_channels, 4, stride=2, padding=1)

        self.down2 = ResBlock(base_channels, base_channels*2, t_emb_dim, use_lip_norm)
        self.pool2 = nn.Conv2d(base_channels*2, base_channels*2, 4, stride=2, padding=1)

        self.down3 = ResBlock(base_channels*2, base_channels*4, t_emb_dim, use_lip_norm)

        # Bottleneck
        self.bot1 = ResBlock(base_channels*4, base_channels*4, t_emb_dim, use_lip_norm)

        # Up
        self.up1     = UpBlock(base_channels*4, base_channels*2)
        self.up_res1 = ResBlock(base_channels*4, base_channels*2, t_emb_dim, use_lip_norm)

        self.up2     = UpBlock(base_channels*2, base_channels)
        self.up_res2 = ResBlock(base_channels*2, base_channels, t_emb_dim, use_lip_norm)

        self.out_conv = nn.Conv2d(base_channels, in_channels, 3, padding=1)

    def forward(self, x, t, y):
        t_emb = get_time_embedding(t, self.t_emb_dim, x.device)
        y_emb = self.label_emb(y)
        emb = self.time_proj(t_emb + y_emb)

        x1 = self.down1(x, emb)
        x2 = self.pool1(x1)

        x2 = self.down2(x2, emb)
        x3 = self.pool2(x2)

        x3 = self.down3(x3, emb)
        bn = self.bot1(x3, emb)

        u1 = self.up1(bn)
        u1 = torch.cat([u1, x2], dim=1) / math.sqrt(2.0)
        u1 = self.up_res1(u1, emb)

        u2 = self.up2(u1)
        u2 = torch.cat([u2, x1], dim=1) / math.sqrt(2.0)
        u2 = self.up_res2(u2, emb)

        return self.out_conv(u2)

# %% [markdown]
# ### DDPM schedule + v-prediction

# %%
class DDPMConfig:
    def __init__(self, timesteps=1000, beta_start=1e-4, beta_end=0.02):
        self.T = timesteps
        self.beta_start = beta_start
        self.beta_end = beta_end

#linear schedule
def make_ddpm_schedule(cfg: DDPMConfig, device):
    betas = torch.linspace(cfg.beta_start, cfg.beta_end, cfg.T, device=device)
    alphas = 1.0 - betas
    alpha_bars = torch.cumprod(alphas, dim=0)
    return betas, alphas, alpha_bars


@torch.no_grad()
def v_to_eps_and_x0(x_t, t, v, alpha_bars):
    ab = alpha_bars[t].view(-1, 1, 1, 1)
    sqrt_ab   = torch.sqrt(ab)
    sqrt_1mab = torch.sqrt(1.0 - ab)
    x0  = sqrt_ab * x_t - sqrt_1mab * v
    eps = sqrt_1mab * x_t + sqrt_ab * v
    return eps, x0

def compute_v_target(x0, eps, t, alpha_bars):
    ab = alpha_bars[t].view(-1, 1, 1, 1)
    return torch.sqrt(ab) * eps - torch.sqrt(1.0 - ab) * x0

# %%
def l2_clip_per_sample(x, clip):
    B = x.shape[0]
    flat = x.view(B, -1)
    norms = torch.linalg.norm(flat, dim=1).clamp(min=1e-12)
    scale = (clip / norms).clamp(max=1.0)
    return (flat * scale[:, None]).view_as(x)

# %%
# function to make MSE loss bounded
def clipped_residual_mse(v_pred, v_target, R):
    r = v_pred - v_target
    r_clipped = l2_clip_per_sample(r, R)
    return r_clipped.pow(2).mean()

# %%
def huber_loss(v_pred, v_target, delta, reduction="mean"):
    """
    SmoothL1 / Huber loss, bounds the per-element gradient dℓ/dr to <= delta (up to reduction scaling).
      - quadratic when |r| < delta
      - linear when |r| >= delta
    """
    return F.smooth_l1_loss(v_pred, v_target, beta=float(delta), reduction=reduction)

# %%
# weight spectral-norm clipping + conservative conv factors
@torch.no_grad()
def power_iter_weight_matrix(w, iters=2, eps=1e-12):
    # w: (out, in_flat)
    u = torch.randn(w.size(0), device=w.device)
    u = u / (u.norm() + eps)
    for _ in range(iters):
        v = (w.t() @ u); v = v / (v.norm() + eps)
        u = (w @ v);     u = u / (u.norm() + eps)
    sigma = torch.dot(u, w @ v).abs()
    return sigma

@torch.no_grad()
def clip_linear_like(module, C, iters=2):
    #clip Conv2d/Linear by spectral norm of flattened weights.
    if not hasattr(module, "weight") or module.weight is None:
        return 1.0
    w = module.weight
    w_mat = w.view(w.shape[0], -1)
    sigma = power_iter_weight_matrix(w_mat, iters=iters)
    # if only when spec norm > D,  then clip.
    if sigma > C:
        module.weight.mul_(C / (sigma + 1e-12))
        sigma = torch.tensor(C, device=w.device)
    return float(sigma)

# %%
def conv_param_factor(conv: nn.Conv2d):
    kh, kw = conv.kernel_size
    # conservative factor (paper-style bound for ∂f/∂W scales with sqrt(window_size))
    return math.sqrt(kh * kw)

# %%
def resblock_lipschitz(block_name, model, sigma_dict):
    """
    block output: (h + skip)/sqrt(2)
    h path ~ sigma(conv2)*sigma(conv1) (GN/act/time -> 1-Lip)
    skip path ~ 1 if identity else sigma(skip_conv)
    """
    inv_sqrt2 = 1.0 / math.sqrt(2.0)
    s1 = sigma_dict.get(f"{block_name}.conv1", 1.0)
    s2 = sigma_dict.get(f"{block_name}.conv2", 1.0)
    blk = getattr(model, block_name)
    if isinstance(blk.skip_conv, nn.Conv2d):
        s_skip = sigma_dict.get(f"{block_name}.skip_conv", 1.0)
    else:
        s_skip = 1.0
    return inv_sqrt2 * (s2 * s1 + s_skip)


def upblock_lipschitz(block_name, sigma_dict):
    return sigma_dict.get(f"{block_name}.conv", 1.0)

def concat_scaled_norm_bound(a_bound, b_bound):
    # concat then /sqrt(2): ||[a,b]||/sqrt(2) <= max(||a||,||b||)
    return max(a_bound, b_bound)

# %%
@torch.no_grad()
def compute_public_activation_bounds(model, sigma, X0):
    """
    Deterministic public propagation of activation norm upper bounds
    through this specific U-Net DAG.
    """
    X = {}
    X["x0"] = float(X0)

    L_down1 = resblock_lipschitz("down1", model, sigma)
    X["x1"] = L_down1 * X["x0"]

    X["x2_in"] = sigma.get("pool1", 1.0) * X["x1"]

    L_down2 = resblock_lipschitz("down2", model, sigma)
    X["x2"] = L_down2 * X["x2_in"]

    X["x3_in"] = sigma.get("pool2", 1.0) * X["x2"]

    L_down3 = resblock_lipschitz("down3", model, sigma)
    X["x3"] = L_down3 * X["x3_in"]

    L_bot = resblock_lipschitz("bot1", model, sigma)
    X["bn"] = L_bot * X["x3"]

    L_up1 = upblock_lipschitz("up1", sigma)
    X["u1_up"] = L_up1 * X["bn"]
    X["u1_cat"] = concat_scaled_norm_bound(X["u1_up"], X["x2"])
    L_upres1 = resblock_lipschitz("up_res1", model, sigma)
    X["u1"] = L_upres1 * X["u1_cat"]

    L_up2 = upblock_lipschitz("up2", sigma)
    X["u2_up"] = L_up2 * X["u1"]
    X["u2_cat"] = concat_scaled_norm_bound(X["u2_up"], X["x1"])
    L_upres2 = resblock_lipschitz("up_res2", model, sigma)
    X["u2"] = L_upres2 * X["u2_cat"]

    return X

# %% [markdown]
# ### DP Engine

# %%
class DPBoundedEngine:
    def __init__(
        self,
        model,
        optimizer,
        C_weight,
        noise_multiplier,
        X0_public,
        Huber_R,
        pi_iters=2,
        clip_every=10,
    ):
        self.model = model
        self.opt = optimizer
        self.C = float(C_weight)
        self.noise_multiplier = float(noise_multiplier)

        self.X0 = float(X0_public)
        self.R = float(Huber_R)

        self.pi_iters = int(pi_iters)
        self.clip_every = int(clip_every)

        self.step_count = 0
        self.sigma = {}
        self.Xbounds = {}
        self.delta_param = {}
        self.delta_global = 0.0
        self.P = 1*28*28

        self.refresh_bounds(force=True)


    @torch.no_grad()
    def add_noise_and_step(self, B: int, debug: bool = True):
        """
        One DP update step with PER-LAYER noise injection:
          - refresh public bounds periodically
          - compute layer-wise sensitivities (delta_k)
          - add Gaussian noise N(0, (noise_multiplier * delta_k)^2 I) to specific layer grads
          - optimizer step and zero grads

        args:
            B: effective batch size for this step (from Poisson sampler)
            debug: if True, prints signal-vs-noise diagnostics occasionally
        """
        self.step_count += 1
        self.refresh_bounds(force=False)

        # 1) Compute sensitivities
        delta_global = float(self.compute_global_sensitivity(B))  # populates self.delta_param (per layer) and returns delta_global


        noised_params = set()

        if self.noise_multiplier > 0:  # when noise_multiplier = 0 basic Lipschitz constrained architecture with no noise training

            for name, mod in self.model.named_modules():
                if isinstance(mod, (nn.Conv2d, nn.Linear)):
                    if hasattr(mod, "weight") and mod.weight is not None and mod.weight.grad is not None:
                        # get specific sensitivity for this layer, fallback to global if missing (shouldn't happen if names match)
                        delta_k = self.delta_param.get(name, delta_global)

                        # calc noise std specific to this layer N(0, sigma^2 * delta_k^2 * I)
                        layer_noise_std = self.noise_multiplier * delta_k

                        # add noise to weights
                        mod.weight.grad.add_(torch.randn_like(mod.weight.grad) * layer_noise_std)
                        noised_params.add(mod.weight)


                        if mod.bias is not None and mod.bias.grad is not None:
                            mod.bias.grad.add_(torch.randn_like(mod.bias.grad) * layer_noise_std)
                            noised_params.add(mod.bias)

            # conservative Global Sensitivity noise to ensure DP safety no for any other param
            fallback_std = self.noise_multiplier * delta_global
            for p in self.model.parameters():
                if p.grad is not None and p not in noised_params:
                    p.grad.add_(torch.randn_like(p.grad) * fallback_std)

        # diagnostics
        if debug and (self.step_count % 50 == 0 or self.step_count <= 5):
            grad_rms_list = []
            for p in self.model.parameters():
                if p.grad is None: continue
                grad_rms_list.append(p.grad.detach().pow(2).mean().sqrt().item())

            avg_grad_rms = float(np.mean(grad_rms_list)) if len(grad_rms_list) > 0 else 0.0
            global_noise_std = self.noise_multiplier * delta_global
            snr = (avg_grad_rms / (global_noise_std + 1e-12)) if global_noise_std > 0 else float("inf")

            print(
                f"[DP step {self.step_count}] B={int(B)} | Δ_global={delta_global:.3e} "
                f"| avg_grad_RMS={avg_grad_rms:.3e} | Approx SNR={snr:.3e}"
            )

        self.opt.step()
        self.opt.zero_grad(set_to_none=True)

    @torch.no_grad()
    def refresh_bounds(self, force: bool = False):
        if (not force) and (self.step_count % self.clip_every != 0):
            return

        self.sigma = {}
        for name, mod in self.model.named_modules():
            if isinstance(mod, (nn.Conv2d, nn.Linear)):
                sig = clip_linear_like(mod, self.C, iters=self.pi_iters)
                self.sigma[name] = min(self.C, float(sig))

        def get_sig(name):
          return self.sigma.get(name, self.C)

        self.Xbounds = compute_public_activation_bounds(self.model, self.sigma, X0=self.X0)

        # time emb inputs
        t_bound = math.sqrt(self.model.t_emb_dim)

        sig_tp0 = get_sig("time_proj.0")
        sig_tp2 = get_sig("time_proj.2")
        emb_bound = sig_tp2 * sig_tp0 * t_bound

        shift_bounds = {
            "down1":    get_sig("down1.time_mlp.1")    * emb_bound,
            "down2":    get_sig("down2.time_mlp.1")    * emb_bound,
            "down3":    get_sig("down3.time_mlp.1")    * emb_bound,
            "bot1":     get_sig("bot1.time_mlp.1")     * emb_bound,
            "up_res1":  get_sig("up_res1.time_mlp.1")  * emb_bound,
            "up_res2":  get_sig("up_res2.time_mlp.1")  * emb_bound }

        self.Xin = {
            # down1
            "down1.conv1": self.Xbounds["x0"],
            "down1.conv2":     get_sig("down1.conv1") * self.Xbounds["x0"] + shift_bounds["down1"],
            # "down1.conv2": self.Xbounds["x0"],
            "down1.skip_conv": self.Xbounds["x0"],

            # pool1
            "pool1":       self.Xbounds["x1"],

            # down2
            "down2.conv1": self.Xbounds["x2_in"],
            # "down2.conv2": self.Xbounds["x2_in"],
            "down2.conv2":     get_sig("down2.conv1") * self.Xbounds["x2_in"]+ shift_bounds["down2"],
            "down2.skip_conv": self.Xbounds["x2_in"],

            # pool2
            "pool2":       self.Xbounds["x2"],


            # down3
            "down3.conv1": self.Xbounds["x3_in"],
            # "down3.conv2": self.Xbounds["x3_in"],
            "down3.conv2":     get_sig("down3.conv1") * self.Xbounds["x3_in"]+shift_bounds["down3"],
            "down3.skip_conv": self.Xbounds["x3_in"],

            # bot1
            "bot1.conv1":  self.Xbounds["x3"],
            # "bot1.conv2":  self.Xbounds["x3"],
            "bot1.conv2":     get_sig("bot1.conv1") * self.Xbounds["x3"]+ shift_bounds["bot1"],
            "bot1.skip_conv": self.Xbounds["x3"],

            #up1
            "up1.conv":      self.Xbounds["bn"],

            #up_res1
            "up_res1.conv1": self.Xbounds["u1_cat"],
            # "up_res1.conv2": self.Xbounds["u1_cat"],
            "up_res1.conv2":     get_sig("up_res1.conv1") * self.Xbounds["u1_cat"] + shift_bounds["up_res1"],
            "up_res1.skip_conv": self.Xbounds["u1_cat"],

            #up2
            "up2.conv":      self.Xbounds["u1"],

            #up_res2
            "up_res2.conv1": self.Xbounds["u2_cat"],
            # "up_res2.conv2": self.Xbounds["u2_cat"],
            "up_res2.conv2":     get_sig("up_res2.conv1") * self.Xbounds["u2_cat"] + shift_bounds["up_res2"],
            "up_res2.skip_conv": self.Xbounds["u2_cat"],

            #output
            "out_conv":    self.Xbounds["u2"],
        }

        self.Xin["time_proj.0"] = t_bound
        self.Xin["time_proj.2"] = t_bound

        for blk in ["down1", "down2", "down3", "bot1", "up_res1", "up_res2"]:
            self.Xin[f"{blk}.time_mlp.1"] = emb_bound

        L_post = {}
        inv_sqrt2 = 1.0 / math.sqrt(2.0)
        L_emb_total = 0.0

        # helper for time MLP injection
        def accumulate_time_sens(blk_name, L_at_injection_point):
            L_post[f"{blk_name}.time_mlp.1"] = L_at_injection_point
            sig_linear = get_sig(f"{blk_name}.time_mlp.1")
            return L_at_injection_point * sig_linear

        # helper for ResBlock Skip conn
        # block output y = (Main(x) + Skip(x)) / sqrt(2)
        # Gradient flow to Skip: L_skip = L_block_output * (1/sqrt(2))
        def handle_skip(blk_name, L_block_out):
            skip_name = f"{blk_name}.skip_conv"
            if skip_name in self.sigma: # only if trainable Conv2d
                L_post[skip_name] = L_block_out * inv_sqrt2

        #  A. Output
        L_post["out_conv"] = 1.0
        L_u2 = 1.0 * get_sig("out_conv")

        #  B. up_res2
        handle_skip("up_res2", L_u2)
        L_post["up_res2.conv2"] = L_u2 * inv_sqrt2
        L_post["up_res2.conv1"] = (L_u2 * inv_sqrt2) * get_sig("up_res2.conv2")

        L_conv2_in = (L_u2 * inv_sqrt2)
        L_emb_total += accumulate_time_sens("up_res2", L_conv2_in)

        L_u2_cat = L_u2 * resblock_lipschitz("up_res2", self.model, self.sigma)
        L_u2_up = L_u2_cat * inv_sqrt2
        L_x1_branch = L_u2_cat * inv_sqrt2

        #  C. up2
        L_post["up2.conv"] = L_u2_up
        L_u1 = L_u2_up * upblock_lipschitz("up2", self.sigma)

        #  D. up_res1
        handle_skip("up_res1", L_u1)
        L_post["up_res1.conv2"] = L_u1 * inv_sqrt2
        L_post["up_res1.conv1"] = (L_u1 * inv_sqrt2) * get_sig("up_res1.conv2")

        L_conv2_in = (L_u1 * inv_sqrt2)
        L_emb_total += accumulate_time_sens("up_res1", L_conv2_in)

        L_u1_cat = L_u1 * resblock_lipschitz("up_res1", self.model, self.sigma)
        L_u1_up = L_u1_cat * inv_sqrt2
        L_x2_branch = L_u1_cat * inv_sqrt2

        #  E. up1
        L_post["up1.conv"] = L_u1_up
        L_bn = L_u1_up * upblock_lipschitz("up1", self.sigma)

        #  F. bot1
        handle_skip("bot1", L_bn)
        L_post["bot1.conv2"] = L_bn * inv_sqrt2
        L_post["bot1.conv1"] = (L_bn * inv_sqrt2) * get_sig("bot1.conv2")

        L_conv2_in = (L_bn * inv_sqrt2)
        L_emb_total += accumulate_time_sens("bot1", L_conv2_in)

        L_x3 = L_bn * resblock_lipschitz("bot1", self.model, self.sigma)

        #  G. down3
        handle_skip("down3", L_x3)
        L_post["down3.conv2"] = L_x3 * inv_sqrt2
        L_post["down3.conv1"] = (L_x3 * inv_sqrt2) * get_sig("down3.conv2")

        L_conv2_in = (L_x3 * inv_sqrt2)
        L_emb_total += accumulate_time_sens("down3", L_conv2_in)

        L_x3_in = L_x3 * resblock_lipschitz("down3", self.model, self.sigma)

        #  H. pool2
        L_post["pool2"] = L_x3_in
        L_x2_main = L_x3_in * get_sig("pool2")
        L_x2_total = L_x2_main + L_x2_branch

        #  I. down2
        handle_skip("down2", L_x2_total)
        L_post["down2.conv2"] = L_x2_total * inv_sqrt2
        L_post["down2.conv1"] = (L_x2_total * inv_sqrt2) * get_sig("down2.conv2")

        L_conv2_in = (L_x2_total * inv_sqrt2)
        L_emb_total += accumulate_time_sens("down2", L_conv2_in)

        L_x2_in = L_x2_total * resblock_lipschitz("down2", self.model, self.sigma)

        #  J. pool1
        L_post["pool1"] = L_x2_in
        L_x1_main = L_x2_in * get_sig("pool1")
        L_x1_total = L_x1_main + L_x1_branch

        # K. down1
        handle_skip("down1", L_x1_total)
        L_post["down1.conv2"] = L_x1_total * inv_sqrt2
        L_post["down1.conv1"] = (L_x1_total * inv_sqrt2) * get_sig("down1.conv2")

        L_conv2_in = (L_x1_total * inv_sqrt2)
        L_emb_total += accumulate_time_sens("down1", L_conv2_in)

        # L. Time Projection
        L_post["time_proj.2"] = L_emb_total
        L_mid = L_emb_total * get_sig("time_proj.2")
        L_post["time_proj.0"] = L_mid

        self.L_post = L_post

    def compute_global_sensitivity(self, B: int):
        # output dimension per sample (MNIST v-pred: 1*28*28)
        P = self.P

        # Huber(mean) => ||dℓ/dv_i||_2 <= R / (B * sqrt(P))
        G = (self.R / math.sqrt(float(P))) / max(int(B), 1) # R is Huber delta


        self.delta_param = {}
        sq_sum = 0.0

        for name, mod in self.model.named_modules():
            if not isinstance(mod, (nn.Conv2d, nn.Linear)) or mod.weight is None:
                continue

            x_in = float(self.Xin.get(name, self.Xbounds["x0"]))
            Kp = 1.0 #conv_param_factor(mod) if isinstance(mod, nn.Conv2d) else 1.0

            Lpost = self.L_post[name]
            delta = G * Lpost * Kp * x_in

            self.delta_param[name] = float(delta)
            sq_sum += float(delta) ** 2

        self.delta_global = math.sqrt(sq_sum) if sq_sum > 0 else 0.0
        return self.delta_global

# %% [markdown]
# ### Trainer (Poisson sampling + K noise draws)

# %%
class DiffusionDPTrainer:
    def __init__(
        self,
        exp_name,
        model,
        ddpm_cfg,
        train_dataset,
        test_dataset,
        q_sample_rate,
        steps,
        lr,
        K_noise_mult,
        ema_decay,
        # DP params
        C_weight,
        noise_multiplier,
        delta,
        # public bounds
        X0_public,
        Huber_R,
        # speed knobs
        pi_iters=2,
        clip_every=10,
    ):
        self.exp_name = exp_name
        self.exp_dir = make_exp_dir(exp_name)

        self.cfg = ddpm_cfg
        self.betas, self.alphas, self.alpha_bars = make_ddpm_schedule(ddpm_cfg, device=device)

        self.model = model.to(device)
        self.ema = EMA(self.model, decay=ema_decay)

        self.opt = torch.optim.Adam(self.model.parameters(), lr=lr)

        self.K = int(K_noise_mult)
        self.steps = int(steps)

        self.q = float(q_sample_rate)
        self.delta = float(delta)
        self.noise_multiplier = float(noise_multiplier)
        self.eps10_saved = False

        self.train_loader = DataLoader(
            train_dataset,
            batch_sampler=UniformWithReplacementSampler(
                num_samples=len(train_dataset),
                sample_rate=self.q,
            ),
            num_workers=0,
            pin_memory=True,
            persistent_workers=False,
        )
        self.test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

        self.accountant = RDPAccountant()

        self.dp_engine = DPBoundedEngine(
            model=self.model,
            optimizer=self.opt,
            C_weight=C_weight,
            noise_multiplier=noise_multiplier,
            X0_public=X0_public,
            Huber_R=Huber_R,
            pi_iters=pi_iters,
            clip_every=clip_every,
        )

        self.history = []

        # define "epoch" under Poisson as ~1/q steps
        self.steps_per_epoch = max(1, int(round(1.0 / self.q)))

    def get_epsilon(self):
        return float(self.accountant.get_epsilon(delta=self.delta))

    def save_checkpoint(self, step):
        ckpt_dir = os.path.join(self.exp_dir, "checkpoints")
        os.makedirs(ckpt_dir, exist_ok=True)
        torch.save(self.model.state_dict(), os.path.join(ckpt_dir, "model_latest.pth"))
        torch.save(self.ema.shadow, os.path.join(ckpt_dir, "ema_latest.pth"))
        torch.save({"step": step, "sigma": self.dp_engine.sigma, "Xbounds": self.dp_engine.Xbounds},
                   os.path.join(ckpt_dir, "bounds_latest.pt"))
        # occasional numbered ckpt
        if step % (self.steps_per_epoch) == 0:
            torch.save(self.model.state_dict(), os.path.join(ckpt_dir, f"model_step{step}.pth"))
            torch.save(self.ema.shadow, os.path.join(ckpt_dir, f"ema_step{step}.pth"))

    @torch.no_grad()
    def sample_grid(self, step, nrow=12, guidance_scale=2.0):
        # 1. SETUP
        self.model.eval()
        # Save a backup of the live weights so we can restore them later
        live_state_dict = {k: v.detach().clone() for k, v in self.model.state_dict().items()}

        # Helper function to run the actual loop (avoids code duplication)
        def generate_and_save(prefix, use_guidance):
            n = nrow * nrow
            x = torch.randn(n, 1, 28, 28, device=device)
            # Digits 0-9 repeating
            y = torch.tensor([i % 10 for i in range(n)], device=device, dtype=torch.long)
            y_null = torch.full_like(y, 10) # Assuming 10 is null class

            for i in reversed(range(self.cfg.T)):
                t = torch.full((n,), i, device=device, dtype=torch.long)

                if use_guidance > 0.0:
                    v_cond = self.model(x, t, y)
                    v_uncond = self.model(x, t, y_null)
                    v_pred = v_uncond + use_guidance * (v_cond - v_uncond)
                else:
                    v_pred = self.model(x, t, y)

                eps_pred, _ = v_to_eps_and_x0(x, t, v_pred, self.alpha_bars)
                alpha = self.alphas[i]
                ab = self.alpha_bars[i]
                beta = self.betas[i]

                mean = (1.0 / torch.sqrt(alpha)) * (x - (beta / torch.sqrt(1.0 - ab)) * eps_pred)
                noise = torch.randn_like(x) if i > 0 else 0.0
                x = mean + torch.sqrt(beta) * noise

            # Save Image
            x_img = (x.clamp(-1, 1) + 1) / 2
            # Filename includes 'EMA' or 'LIVE'
            out_path = os.path.join(self.exp_dir, "samples", f"{prefix}_step{step:06d}.png")
            save_image(make_grid(x_img, nrow=nrow), out_path)
            return out_path

        # ema models sampls
        self.ema.copy_to(self.model) # EMA weights
        generate_and_save(prefix="EMA_grid", use_guidance=guidance_scale)

        # original models samples
        self.model.load_state_dict(live_state_dict) # live weights
        generate_and_save(prefix="LIVE_grid", use_guidance=guidance_scale)

        self.model.train()

    def train(self, log_every=50):
        print(f"[{self.exp_name}] Poisson sampling q={self.q:.6f} | steps={self.steps} | ~{self.steps_per_epoch} steps/epoch")
        step = 0
        loader_iter = iter(self.train_loader)

        pbar = tqdm(range(1, self.steps + 1))
        for _ in pbar:
            step += 1
            epoch = (step - 1) // self.steps_per_epoch + 1
            is_epoch_end = (step % self.steps_per_epoch == 0)

            try:
                batch = next(loader_iter)
            except StopIteration:
                loader_iter = iter(self.train_loader)
                batch = next(loader_iter)

            x0, y0 = batch
            x0 = x0.to(device, non_blocking=True)
            y0 = y0.to(device, non_blocking=True)
            B = x0.size(0)

            # enforce public input bound
            x0 = l2_clip_per_sample(x0, clip=self.dp_engine.X0)

            # classifier-free dropout on labels
            drop_mask = (torch.rand(B, device=device) < 0.1)
            y_train = y0.clone()
            y_train[drop_mask] = 10

            self.opt.zero_grad(set_to_none=True)

            loss_accum = 0.0
            for _k in range(self.K):
                t = torch.randint(0, self.cfg.T, (B,), device=device).long()
                eps = torch.randn_like(x0)
                ab = self.alpha_bars[t].view(-1, 1, 1, 1)
                x_t = torch.sqrt(ab) * x0 + torch.sqrt(1.0 - ab) * eps

                v_target = compute_v_target(x0, eps, t, self.alpha_bars)
                v_pred   = self.model(x_t, t, y_train)

                # bounded loss gradient (DP-valid)
                # loss = clipped_residual_mse(v_pred, v_target, R=self.dp_engine.R)
                loss = huber_loss(v_pred, v_target, delta=self.dp_engine.R)
                (loss / self.K).backward()
                loss_accum += float(loss.item())

            # DP step (adds noise + weight clipping periodically inside engine)
            self.dp_engine.add_noise_and_step(B)
            self.ema.update(self.model)

            # accountant (subsampled Gaussian mechanism, one step)
            if self.noise_multiplier > 0:
                self.accountant.step(noise_multiplier=self.noise_multiplier, sample_rate=self.q)

            avg_loss = loss_accum / self.K
            eps_now = self.get_epsilon()
            EPS_MAX = 10.5

            if eps_now >= EPS_MAX and not self.eps10_saved: # Capture Epsilon=10
                ckpt_dir = os.path.join(self.exp_dir, "checkpoints")
                os.makedirs(ckpt_dir, exist_ok=True)
                torch.save(self.model.state_dict(), os.path.join(ckpt_dir, "model_eps10.pth"))
                torch.save(self.ema.shadow, os.path.join(ckpt_dir, "ema_eps10.pth"))
                self.eps10_saved = True

            if eps_now >= EPS_MAX:
                print(f"Stopping: epsilon reached {eps_now:.2f} (>= {EPS_MAX}) at step {step}")
                self.save_checkpoint(step)
                self.sample_grid(step, guidance_scale=0.0)
                break


            if step % log_every == 0:
                pbar.set_postfix(
                    loss=f"{avg_loss:.4f}",
                    eps=f"{eps_now:.2f}",
                    B=B,
                    dG=f"{self.dp_engine.delta_global:.3e}",
                    ep=epoch
                )

            if step % log_every == 0 or step == 1:
                # history csv
                self.history.append({
                    "step": step,
                    "epoch": epoch,
                    "loss": avg_loss,
                    "epsilon": eps_now,
                    "batch_size_effective": B,
                    "delta_global": float(self.dp_engine.delta_global),
                })
                pd.DataFrame(self.history).to_csv(os.path.join(self.exp_dir, "metrics", "train_history.csv"), index=False)

                # diagnostics JSON (sensitivities + public bounds)
                diag = {
                    "step": step,
                    "epoch": epoch,
                    "loss": avg_loss,
                    "epsilon": eps_now,
                    "B_effective": int(B),
                    "delta_global": float(self.dp_engine.delta_global),
                    "delta_per_layer": self.dp_engine.delta_param,
                    "X_bounds": self.dp_engine.Xbounds,
                    "sigmas": self.dp_engine.sigma,
                    "X0_public": float(self.dp_engine.X0),
                    "Huber_R": float(self.dp_engine.R),
                    "noise_multiplier": float(self.noise_multiplier),
                    "C_weight": float(self.dp_engine.C),
                    "clip_every": int(self.dp_engine.clip_every),
                    "pi_iters": int(self.dp_engine.pi_iters),
                }
                save_json(diag, os.path.join(self.exp_dir, "diagnostics", f"diag_step{step:06d}.json"))

            # checkpoints & samples per Poisson-epoch
            if is_epoch_end or step == self.steps:
                self.save_checkpoint(step)
                self.sample_grid(step, guidance_scale=2.0)

# %% [markdown]
# ### Downstream Evaluation

# %%
def prepare_real_images_folder(dataset, output_folder, num_images=20000):
    os.makedirs(output_folder, exist_ok=True)
    existing = len([f for f in os.listdir(output_folder) if f.endswith(".png")])
    if existing >= num_images:
        return output_folder

    loader = DataLoader(dataset, batch_size=1, shuffle=True, drop_last=False)
    i = 0
    for img, _ in tqdm(loader, total=num_images, desc="Saving real images"):
        if i >= num_images:
            break
        img = img.squeeze(0)
        img01 = (img + 1) / 2
        save_image(img01, os.path.join(output_folder, f"real_{i:06d}.png"))
        i += 1
    return output_folder

# %%
def compute_fid_and_is(gen_dir, real_dir, use_cuda=True):
    metrics = calculate_metrics(
        input1=gen_dir,
        input2=real_dir,
        cuda=use_cuda,
        fid=True,
        isc=True,
        verbose=False
    )
    return {
        "FID": float(metrics["frechet_inception_distance"]),
        "IS_mean": float(metrics["inception_score_mean"]),
        "IS_std": float(metrics["inception_score_std"]),
    }

# %%
class SynthMNISTDataset(torch.utils.data.Dataset):
    def __init__(self, pt_path):
        d = torch.load(pt_path, map_location="cpu")
        self.images_u8 = d["images_u8"]
        self.labels = d["labels"]

    def __len__(self):
        return int(self.labels.shape[0])

    def __getitem__(self, idx):
        x = self.images_u8[idx].float() / 255.0
        x = (x * 2) - 1
        y = self.labels[idx].long()
        return x, y

# %% [markdown]
# #### NN Classifiers

# %%
class MLPClassifier(nn.Module):
    def __init__(self, hidden=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(28*28, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 10)
        )
    def forward(self, x):
        return self.net(x.view(x.size(0), -1))

class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.fc = nn.Sequential(
            nn.Linear(64*7*7, 128), nn.ReLU(),
            nn.Linear(128, 10)
        )
    def forward(self, x):
        h = self.conv(x)
        h = h.view(h.size(0), -1)
        return self.fc(h)

@torch.no_grad()
def eval_accuracy(model, loader, device):
    model.eval()
    correct, total = 0, 0
    for x, y in loader:
        x = x.to(device); y = y.to(device)
        pred = model(x).argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()
    return correct / total

def train_classifier(model, train_loader, test_loader, device, epochs=10, lr=1e-3):
    model = model.to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    ce = nn.CrossEntropyLoss()

    for ep in range(1, epochs + 1):
        model.train()
        for x, y in tqdm(train_loader, desc=f"[clf] ep {ep}/{epochs}", leave=False):
            x = x.to(device); y = y.to(device)
            loss = ce(model(x), y)
            opt.zero_grad(set_to_none=True)
            loss.backward()
            opt.step()

    return eval_accuracy(model, test_loader, device)

# %%
def downstream_eval_nn(synth_pt_path, mnist_test_ds, out_dir, device, batch_size=256):
    os.makedirs(out_dir, exist_ok=True)

    synth_ds = SynthMNISTDataset(synth_pt_path)
    synth_loader = DataLoader(synth_ds, batch_size=batch_size, shuffle=True, drop_last=False, num_workers=2)
    test_loader = DataLoader(mnist_test_ds, batch_size=batch_size, shuffle=False, drop_last=False, num_workers=2)

    results = {}
    results["mlp"] = float(train_classifier(MLPClassifier(), synth_loader, test_loader, device=device, epochs=10, lr=1e-3))
    results["cnn"] = float(train_classifier(SimpleCNN(), synth_loader, test_loader, device=device, epochs=10, lr=1e-3))

    save_json(results, os.path.join(out_dir, "downstream_accuracy_nn.json"))
    pd.DataFrame([results]).to_csv(os.path.join(out_dir, "downstream_accuracy_nn.csv"), index=False)
    return results

# %%
def load_synth_pt_to_numpy(synth_pt_path):
    d = torch.load(synth_pt_path, map_location="cpu")
    # Convert from uint8 [0, 255] to float [0, 1]
    X = d["images_u8"].numpy().astype(np.float32) / 255.0
    # Flatten (N, 1, 28, 28) -> (N, 784)
    X = X.reshape(X.shape[0], -1)
    y = d["labels"].numpy().astype(np.int64)
    return X, y

def load_real_mnist_test_to_numpy(mnist_test_ds):
    loader = DataLoader(mnist_test_ds, batch_size=512, shuffle=False)
    X_list, y_list = [], []
    for x, y in loader:
        # check if x is already [0, 1] or [-1, 1], map to [0, 1] to match synthetic loading
        x = ((x + 1) / 2).numpy().astype(np.float32)
        X_list.append(x.reshape(x.shape[0], -1))
        y_list.append(y.numpy().astype(np.int64))
    return np.concatenate(X_list, axis=0), np.concatenate(y_list, axis=0)


# sklearn models as downstream classifiers: LogReg, DT, RF
def downstream_eval_sklearn(synth_pt_path, mnist_test_ds, out_dir, random_state=42):
    os.makedirs(out_dir, exist_ok=True)

    print("Loading data for sklearn eval...")
    X_train, y_train = load_synth_pt_to_numpy(synth_pt_path)
    X_test, y_test = load_real_mnist_test_to_numpy(mnist_test_ds)

    results = {}

    print("\n[sklearn] LogisticRegression...")
    logreg = LogisticRegression(max_iter=1000, solver="lbfgs", n_jobs=-1)
    logreg.fit(X_train, y_train)
    results["logreg"] = float(accuracy_score(y_test, logreg.predict(X_test)))
    print("  test_acc:", results["logreg"])

    print("\n[sklearn] DecisionTree...")
    dt = DecisionTreeClassifier(random_state=random_state)
    dt.fit(X_train, y_train)
    results["decision_tree"] = float(accuracy_score(y_test, dt.predict(X_test)))
    print("  test_acc:", results["decision_tree"])

    print("\n[sklearn] RandomForest...")
    rf = RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=random_state)
    rf.fit(X_train, y_train)
    results["random_forest"] = float(accuracy_score(y_test, rf.predict(X_test)))
    print("  test_acc:", results["random_forest"])

    save_json(results, os.path.join(out_dir, "downstream_accuracy_sklearn.json"))
    pd.DataFrame([results]).to_csv(os.path.join(out_dir, "downstream_accuracy_sklearn.csv"), index=False)
    return results

# %%
@torch.no_grad()
def export_png_folder_for_fid_is(model, ema: EMA, cfg, alphas, alpha_bars, betas,
                                 out_dir, n_samples=20000, batch_size=256,
                                 guidance_scale=1.0, use_ema=True): #  use_ema
    os.makedirs(out_dir, exist_ok=True)
    model.eval()

    # backupu weights
    backup = {k: v.detach().clone() for k, v in model.state_dict().items()}

    # conditionall load EMA
    if use_ema:
        print("--> Loading EMA weights for PNG export...")
        ema.copy_to(model)
    else:
        print("--> Using LIVE weights for PNG export...")

    n_done = 0
    num_batches = (n_samples + batch_size - 1) // batch_size
    for _ in tqdm(range(num_batches), desc=f"Export PNGs (EMA={use_ema})"):
        cur = min(batch_size, n_samples - n_done)
        if cur <= 0:
            break
        x = torch.randn(cur, 1, 28, 28, device=device)
        y = torch.randint(0, 10, (cur,), device=device, dtype=torch.long)
        y_null = torch.full_like(y, 10)

        for i in reversed(range(cfg.T)):
            t = torch.full((cur,), i, device=device, dtype=torch.long)
            if guidance_scale > 0.0:
                v_cond   = model(x, t, y)
                v_uncond = model(x, t, y_null)
                v_pred   = v_uncond + guidance_scale * (v_cond - v_uncond)
            else:
                v_pred = model(x, t, y)

            eps_pred, _ = v_to_eps_and_x0(x, t, v_pred, alpha_bars)
            alpha = alphas[i]
            ab    = alpha_bars[i]
            beta  = betas[i]
            mean = (1.0 / torch.sqrt(alpha)) * (x - (beta / torch.sqrt(1.0 - ab)) * eps_pred)
            noise = torch.randn_like(x) if i > 0 else 0.0
            x = mean + torch.sqrt(beta) * noise

        x01 = (x.clamp(-1, 1) + 1) / 2
        for k in range(cur):
            save_image(x01[k].cpu(), os.path.join(out_dir, f"gen_{n_done+k:06d}.png"))
        n_done += cur

    model.load_state_dict(backup)
    model.train()
    return out_dir

@torch.no_grad()
def generate_synthetic_pt(model, ema: EMA, cfg, alphas, alpha_bars, betas,
                          out_path, n_samples=60000, batch_size=256,
                          guidance_scale=1.0, use_ema=True): # <--- Added use_ema
    model.eval()
    backup = {k: v.detach().clone() for k, v in model.state_dict().items()}

    if use_ema:
        print("Loading EMA weights for PT generation...")
        ema.copy_to(model)
    else:
        print("Using LIVE weights for PT generation...")

    img_list, lab_list = [], []
    n_done = 0
    num_batches = (n_samples + batch_size - 1) // batch_size

    for _ in tqdm(range(num_batches), desc=f"Generate synth {n_samples} (EMA={use_ema})"):
        cur = min(batch_size, n_samples - n_done)
        if cur <= 0:
            break

        x = torch.randn(cur, 1, 28, 28, device=device)
        y = torch.randint(0, 10, (cur,), device=device, dtype=torch.long)
        y_null = torch.full_like(y, 10)

        for i in reversed(range(cfg.T)):
            t = torch.full((cur,), i, device=device, dtype=torch.long)
            if guidance_scale > 0.0:
                v_cond   = model(x, t, y)
                v_uncond = model(x, t, y_null)
                v_pred   = v_uncond + guidance_scale * (v_cond - v_uncond)
            else:
                v_pred = model(x, t, y)

            eps_pred, _ = v_to_eps_and_x0(x, t, v_pred, alpha_bars)
            alpha = alphas[i]
            ab    = alpha_bars[i]
            beta  = betas[i]
            mean = (1.0 / torch.sqrt(alpha)) * (x - (beta / torch.sqrt(1.0 - ab)) * eps_pred)
            x = mean + (torch.sqrt(beta) * torch.randn_like(x) if i > 0 else 0.0)

        x01 = (x.clamp(-1, 1) + 1) / 2
        x_u8 = (x01 * 255.0).round().to(torch.uint8).cpu()

        img_list.append(x_u8)
        lab_list.append(y.cpu())
        n_done += cur

    images = torch.cat(img_list, dim=0)[:n_samples]
    labels = torch.cat(lab_list, dim=0)[:n_samples]

    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    torch.save({"images_u8": images, "labels": labels}, out_path)

    model.load_state_dict(backup)
    model.train()
    return out_path

# %%
def evaluate_trainer(trainer: DiffusionDPTrainer,
                     mnist_train_ds,
                     mnist_test_ds,
                     fid_is_n=20000,
                     synth_n=60000,
                     guidance_scale=1.0,
                     use_ema=True):

    model_type = "ema" if use_ema else "live"

    metrics_dir = os.path.join(trainer.exp_dir, "metrics")
    os.makedirs(metrics_dir, exist_ok=True)
    synth_pt_path = os.path.join(trainer.exp_dir, "synthetic_data", f"synth_{synth_n}_w{guidance_scale}_{model_type}.pt")

    synth_pt = generate_synthetic_pt(
        trainer.model, trainer.ema, trainer.cfg,
        trainer.alphas, trainer.alpha_bars, trainer.betas,
        out_path=synth_pt_path,
        n_samples=synth_n,
        batch_size=256,
        guidance_scale=guidance_scale,
        use_ema=use_ema # Pass flag
    )

    real_dir = os.path.join(RUN_DIR, "fid_is_real_mnist_train_20k")
    prepare_real_images_folder(mnist_train_ds, real_dir, num_images=fid_is_n)
    gen_dir = os.path.join(trainer.exp_dir, "fid_is", f"gen_{fid_is_n}_w{guidance_scale}_{model_type}")

    export_png_folder_for_fid_is(
        trainer.model, trainer.ema, trainer.cfg,
        trainer.alphas, trainer.alpha_bars, trainer.betas,
        out_dir=gen_dir,
        n_samples=fid_is_n,
        batch_size=256,
        guidance_scale=guidance_scale,
        use_ema=use_ema
    )

    fidis = compute_fid_and_is(gen_dir, real_dir, use_cuda=torch.cuda.is_available())
    save_json(fidis, os.path.join(metrics_dir, f"fid_is_{fid_is_n}_{model_type}_w{guidance_scale}.json"))

    print(f"\n--- Running Downstream Evaluation (Model: {model_type}, w={guidance_scale}) ---")
    nn_res = downstream_eval_nn(synth_pt, mnist_test_ds, metrics_dir, device=device)
    sklearn_res = downstream_eval_sklearn(synth_pt, mnist_test_ds, metrics_dir)

    combined = {
        "exp_name": trainer.exp_name,
        "epsilon_final": trainer.get_epsilon(),
        "model_type": model_type,
        "guidance_scale": guidance_scale,
        "FID": fidis["FID"],
        "IS_mean": fidis["IS_mean"],
        "IS_std": fidis["IS_std"],
        "downstream_nn": nn_res,
        "downstream_sklearn": sklearn_res,
    }

    save_json(combined, os.path.join(metrics_dir, f"all_metrics_{model_type}_w{guidance_scale}.json"))
    return combined

# %%
ddpm_cfg = DDPMConfig(timesteps=1000, beta_start=1e-4, beta_end=0.02)

N = len(mnist_train)
q = 2048 / N
steps = 10000
lr = 1e-4
K_MULT = 16
EMA_DECAY = 0.999

# DP settings
C_WEIGHT = 1.3
NOISE_MULT = 1.2
DELTA = 1e-5

X0_PUBLIC = 28.0        # sqrt(784) for MNIST in [-1,1]
Huber_R = 1.0

PI_ITERS = 2
CLIP_EVERY = 20

exp_name = (
    f"2DP_Diffusion_NoGradClip_publicBounds_q{q:.6f}_steps{steps}_K{K_MULT}"
    f"_C{C_WEIGHT}_nm{NOISE_MULT}_X0{X0_PUBLIC}_R{Huber_R}"
    f"_pi{PI_ITERS}_clipEvery{CLIP_EVERY}"
)

model = CondDiffUNet(
    n_classes=11,
    base_channels=32,
    use_lip_norm=False,
).to(device)

# %%
from opacus.accountants.utils import get_noise_multiplier

target_epsilon = 10.0
target_delta = 1e-5
sample_rate = 2048 / 60000
steps = 6000

sigma = get_noise_multiplier(
    target_epsilon=target_epsilon,
    target_delta=target_delta,
    sample_rate=sample_rate,
    epochs=steps * sample_rate
)

print(f"To reach epsilon={target_epsilon} at step {steps}, use noise_multiplier={sigma:.4f}")
# Out:
# To reach epsilon=10.0 at step 6000, use noise_multiplier=1.5747

# %%
ddpm_cfg = DDPMConfig(timesteps=1000, beta_start=1e-4, beta_end=0.02)

N = len(mnist_train)
q = 2048 / N
steps = 6000
lr = 5e-5
K_MULT = 16
EMA_DECAY = 0.999

# DP settings
C_WEIGHT = 1.3
NOISE_MULT = 1.3
DELTA = 1e-5

X0_PUBLIC = 28.0        # sqrt(784) for MNIST in [-1,1]
Huber_R = 0.5

PI_ITERS = 2
CLIP_EVERY = 20

exp_name = (
    f"improved_eps10_DP_Diffusion_NoGradClip_publicBounds_q{q:.6f}_steps{steps}_K{K_MULT}"
    f"_C{C_WEIGHT}_nm{NOISE_MULT}_X0{X0_PUBLIC}_R{Huber_R}"
    f"_pi{PI_ITERS}_clipEvery{CLIP_EVERY}"
)

model = CondDiffUNet(
    n_classes=11,
    base_channels=32,
    use_lip_norm=False,
).to(device)

# %%
trainer2 = DiffusionDPTrainer(
    exp_name=exp_name,
    model=model,
    ddpm_cfg=ddpm_cfg,
    train_dataset=mnist_train,
    test_dataset=mnist_test,
    q_sample_rate=q,
    steps=steps,
    lr=lr,
    K_noise_mult=K_MULT,
    ema_decay=EMA_DECAY,
    C_weight=C_WEIGHT,
    noise_multiplier=NOISE_MULT,
    delta=DELTA,
    X0_public=X0_PUBLIC,
    Huber_R=Huber_R,
    pi_iters=PI_ITERS,
    clip_every=CLIP_EVERY,
)

trainer2.train(log_every=50)
# Out:
# [improved_eps10_DP_Diffusion_NoGradClip_publicBounds_q0.034133_steps6000_K16_C1.3_nm1.3_X028.0_R0.5_pi2_clipEvery20] Poisson sampling q=0.034133 | steps=6000 | ~29 steps/epoch
#   0%|                                            | 1/6000 [00:01<3:01:56,  1.82s/it]
# [DP step 1] B=2050 | Δ=4.895e-04 | noise_std=6.363e-04 | avg_grad_RMS=2.503e-02 | RMS/noise=3.933e+01
#   0%|                                            | 2/6000 [00:03<2:58:32,  1.79s/it]
# [DP step 2] B=2030 | Δ=4.943e-04 | noise_std=6.426e-04 | avg_grad_RMS=2.316e-02 | RMS/noise=3.604e+01
#   0%|                                            | 3/6000 [00:05<3:03:01,  1.83s/it]
# [DP step 3] B=2173 | Δ=4.618e-04 | noise_std=6.003e-04 | avg_grad_RMS=2.101e-02 | RMS/noise=3.501e+01
#   0%|                                            | 4/6000 [00:07<2:59:51,  1.80s/it]
# [DP step 4] B=2011 | Δ=4.990e-04 | noise_std=6.486e-04 | avg_grad_RMS=1.904e-02 | RMS/noise=2.936e+01
#   0%|                                            | 5/6000 [00:09<2:59:15,  1.79s/it]
# [DP step 5] B=2063 | Δ=4.864e-04 | noise_std=6.323e-04 | avg_grad_RMS=1.716e-02 | RMS/noise=2.713e+01
#   1%| | 50/6000 [01:43<2:58:46,  1.80s/it, B=2116, dG=4.758e-04, ep=2, eps=1.28, los
# [DP step 50] B=2116 | Δ=4.758e-04 | noise_std=6.185e-04 | avg_grad_RMS=1.290e-03 | RMS/noise=2.086e+00
#   2%| | 100/6000 [03:40<3:00:49,  1.84s/it, B=2089, dG=4.792e-04, ep=4, eps=1.63, lo
# [DP step 100] B=2089 | Δ=4.792e-04 | noise_std=6.230e-04 | avg_grad_RMS=4.407e-04 | RMS/noise=7.073e-01
#   2%| | 150/6000 [05:38<4:02:15,  2.48s/it, B=1955, dG=4.499e-04, ep=6, eps=1.93, lo
# [DP step 150] B=1955 | Δ=4.499e-04 | noise_std=5.849e-04 | avg_grad_RMS=4.051e-04 | RMS/noise=6.927e-01
#   3%| | 200/6000 [07:21<2:53:46,  1.80s/it, B=2091, dG=4.375e-04, ep=7, eps=2.19, lo
# [DP step 200] B=2091 | Δ=4.375e-04 | noise_std=5.688e-04 | avg_grad_RMS=2.791e-04 | RMS/noise=4.906e-01
#   4%| | 250/6000 [09:18<2:51:15,  1.79s/it, B=2072, dG=4.843e-04, ep=9, eps=2.42, lo
# [DP step 250] B=2072 | Δ=4.843e-04 | noise_std=6.296e-04 | avg_grad_RMS=4.090e-04 | RMS/noise=6.496e-01
#   5%| | 300/6000 [11:17<3:03:25,  1.93s/it, B=2084, dG=4.330e-04, ep=11, eps=2.64, l
# [DP step 300] B=2084 | Δ=4.330e-04 | noise_std=5.629e-04 | avg_grad_RMS=1.795e-04 | RMS/noise=3.189e-01
#   6%| | 350/6000 [13:15<6:06:02,  3.89s/it, B=2058, dG=4.930e-04, ep=13, eps=2.85, l
# [DP step 350] B=2058 | Δ=4.930e-04 | noise_std=6.409e-04 | avg_grad_RMS=3.346e-04 | RMS/noise=5.220e-01
#   7%| | 400/6000 [14:59<2:47:05,  1.79s/it, B=2045, dG=4.631e-04, ep=14, eps=3.04, l
# [DP step 400] B=2045 | Δ=4.631e-04 | noise_std=6.021e-04 | avg_grad_RMS=2.850e-04 | RMS/noise=4.734e-01
#   8%| | 450/6000 [16:57<2:48:38,  1.82s/it, B=2048, dG=4.926e-04, ep=16, eps=3.22, l
# [DP step 450] B=2048 | Δ=4.926e-04 | noise_std=6.404e-04 | avg_grad_RMS=2.267e-04 | RMS/noise=3.540e-01
#   8%| | 500/6000 [18:56<3:14:00,  2.12s/it, B=1991, dG=5.114e-04, ep=18, eps=3.40, l
# [DP step 500] B=1991 | Δ=5.114e-04 | noise_std=6.649e-04 | avg_grad_RMS=1.251e-03 | RMS/noise=1.882e+00
#   9%| | 550/6000 [20:39<2:46:24,  1.83s/it, B=1913, dG=4.875e-04, ep=19, eps=3.57, l
# [DP step 550] B=1913 | Δ=4.875e-04 | noise_std=6.338e-04 | avg_grad_RMS=6.647e-04 | RMS/noise=1.049e+00
#  10%| | 600/6000 [22:36<2:42:08,  1.80s/it, B=2096, dG=4.555e-04, ep=21, eps=3.73, l
# [DP step 600] B=2096 | Δ=4.555e-04 | noise_std=5.921e-04 | avg_grad_RMS=4.424e-04 | RMS/noise=7.471e-01
#  11%| | 650/6000 [24:36<2:49:43,  1.90s/it, B=2030, dG=4.647e-04, ep=23, eps=3.89, l
# [DP step 650] B=2030 | Δ=4.647e-04 | noise_std=6.041e-04 | avg_grad_RMS=5.382e-04 | RMS/noise=8.910e-01
#  12%| | 700/6000 [26:33<4:12:57,  2.86s/it, B=2060, dG=4.483e-04, ep=25, eps=4.04, l
# [DP step 700] B=2060 | Δ=4.483e-04 | noise_std=5.828e-04 | avg_grad_RMS=1.850e-03 | RMS/noise=3.173e+00
#  12%|▏| 750/6000 [28:16<2:34:57,  1.77s/it, B=2025, dG=4.632e-04, ep=26, eps=4.19, l
# [DP step 750] B=2025 | Δ=4.632e-04 | noise_std=6.021e-04 | avg_grad_RMS=2.200e-03 | RMS/noise=3.654e+00
#  13%|▏| 800/6000 [30:14<2:35:26,  1.79s/it, B=2029, dG=4.553e-04, ep=28, eps=4.33, l
# [DP step 800] B=2029 | Δ=4.553e-04 | noise_std=5.919e-04 | avg_grad_RMS=8.351e-04 | RMS/noise=1.411e+00
#  14%|▏| 850/6000 [32:12<2:48:01,  1.96s/it, B=2043, dG=4.412e-04, ep=30, eps=4.47, l
# [DP step 850] B=2043 | Δ=4.412e-04 | noise_std=5.736e-04 | avg_grad_RMS=2.810e-04 | RMS/noise=4.899e-01
#  15%|▏| 900/6000 [34:10<6:48:27,  4.81s/it, B=2011, dG=4.877e-04, ep=32, eps=4.61, l
# [DP step 900] B=2011 | Δ=4.877e-04 | noise_std=6.340e-04 | avg_grad_RMS=6.367e-04 | RMS/noise=1.004e+00
#  16%|▏| 950/6000 [35:53<2:33:25,  1.82s/it, B=2116, dG=4.505e-04, ep=33, eps=4.74, l
# [DP step 950] B=2116 | Δ=4.505e-04 | noise_std=5.857e-04 | avg_grad_RMS=4.849e-04 | RMS/noise=8.279e-01
#  17%|▏| 1000/6000 [37:51<2:30:06,  1.80s/it, B=2028, dG=4.750e-04, ep=35, eps=4.87,
# [DP step 1000] B=2028 | Δ=4.750e-04 | noise_std=6.176e-04 | avg_grad_RMS=5.166e-04 | RMS/noise=8.366e-01
#  18%|▏| 1050/6000 [39:48<3:09:28,  2.30s/it, B=2085, dG=4.283e-04, ep=37, eps=5.00,
# [DP step 1050] B=2085 | Δ=4.283e-04 | noise_std=5.568e-04 | avg_grad_RMS=1.164e-03 | RMS/noise=2.090e+00
#  18%|▏| 1100/6000 [41:32<2:27:29,  1.81s/it, B=2062, dG=4.806e-04, ep=38, eps=5.13,
# [DP step 1100] B=2062 | Δ=4.806e-04 | noise_std=6.248e-04 | avg_grad_RMS=7.861e-04 | RMS/noise=1.258e+00
#  19%|▏| 1150/6000 [43:31<2:25:38,  1.80s/it, B=2077, dG=4.861e-04, ep=40, eps=5.25,
# [DP step 1150] B=2077 | Δ=4.861e-04 | noise_std=6.319e-04 | avg_grad_RMS=8.034e-04 | RMS/noise=1.271e+00
#  20%|▏| 1200/6000 [45:28<2:29:42,  1.87s/it, B=2061, dG=4.429e-04, ep=42, eps=5.37,
# [DP step 1200] B=2061 | Δ=4.429e-04 | noise_std=5.757e-04 | avg_grad_RMS=5.660e-04 | RMS/noise=9.831e-01
#  21%|▏| 1250/6000 [47:26<4:16:10,  3.24s/it, B=2058, dG=4.906e-04, ep=44, eps=5.49,
# [DP step 1250] B=2058 | Δ=4.906e-04 | noise_std=6.378e-04 | avg_grad_RMS=6.431e-04 | RMS/noise=1.008e+00
#  22%|▏| 1300/6000 [49:10<2:19:13,  1.78s/it, B=2032, dG=4.835e-04, ep=45, eps=5.61,
# [DP step 1300] B=2032 | Δ=4.835e-04 | noise_std=6.285e-04 | avg_grad_RMS=5.300e-04 | RMS/noise=8.433e-01
#  22%|▏| 1350/6000 [51:08<2:18:15,  1.78s/it, B=1993, dG=4.964e-04, ep=47, eps=5.73,
# [DP step 1350] B=1993 | Δ=4.964e-04 | noise_std=6.454e-04 | avg_grad_RMS=9.286e-04 | RMS/noise=1.439e+00
#  23%|▏| 1400/6000 [53:07<2:39:04,  2.07s/it, B=2047, dG=4.722e-04, ep=49, eps=5.84,
# [DP step 1400] B=2047 | Δ=4.722e-04 | noise_std=6.138e-04 | avg_grad_RMS=6.794e-04 | RMS/noise=1.107e+00
#  24%|▏| 1449/6000 [54:53<2:15:13,  1.78s/it, B=2081, dG=4.717e-04, ep=50, eps=5.96,
# [DP step 1450] B=2081 | Δ=4.717e-04 | noise_std=6.132e-04 | avg_grad_RMS=1.030e-03 | RMS/noise=1.680e+00
#  25%|▎| 1500/6000 [56:52<2:15:12,  1.80s/it, B=1972, dG=4.912e-04, ep=52, eps=6.07,
# [DP step 1500] B=1972 | Δ=4.912e-04 | noise_std=6.386e-04 | avg_grad_RMS=5.189e-04 | RMS/noise=8.126e-01
#  26%|▎| 1550/6000 [58:49<2:16:00,  1.83s/it, B=2061, dG=4.429e-04, ep=54, eps=6.18,
# [DP step 1550] B=2061 | Δ=4.429e-04 | noise_std=5.757e-04 | avg_grad_RMS=9.534e-04 | RMS/noise=1.656e+00
#  27%|▎| 1600/6000 [1:00:47<3:06:12,  2.54s/it, B=2092, dG=4.730e-04, ep=56, eps=6.29
# [DP step 1600] B=2092 | Δ=4.730e-04 | noise_std=6.149e-04 | avg_grad_RMS=9.477e-04 | RMS/noise=1.541e+00
#  28%|▎| 1650/6000 [1:02:32<2:11:38,  1.82s/it, B=2039, dG=4.876e-04, ep=57, eps=6.39
# [DP step 1650] B=2039 | Δ=4.876e-04 | noise_std=6.339e-04 | avg_grad_RMS=6.606e-04 | RMS/noise=1.042e+00
#  28%|▎| 1700/6000 [1:04:30<2:07:25,  1.78s/it, B=2062, dG=4.731e-04, ep=59, eps=6.50
# [DP step 1700] B=2062 | Δ=4.731e-04 | noise_std=6.150e-04 | avg_grad_RMS=1.113e-03 | RMS/noise=1.809e+00
#  29%|▎| 1750/6000 [1:06:27<2:14:20,  1.90s/it, B=2094, dG=4.356e-04, ep=61, eps=6.61
# [DP step 1750] B=2094 | Δ=4.356e-04 | noise_std=5.663e-04 | avg_grad_RMS=8.677e-04 | RMS/noise=1.532e+00
#  30%|▎| 1800/6000 [1:08:26<4:31:08,  3.87s/it, B=2055, dG=4.742e-04, ep=63, eps=6.71
# [DP step 1800] B=2055 | Δ=4.742e-04 | noise_std=6.165e-04 | avg_grad_RMS=1.099e-03 | RMS/noise=1.782e+00
#  31%|▎| 1850/6000 [1:10:09<2:03:25,  1.78s/it, B=2040, dG=4.686e-04, ep=64, eps=6.81
# [DP step 1850] B=2040 | Δ=4.686e-04 | noise_std=6.091e-04 | avg_grad_RMS=4.642e-04 | RMS/noise=7.621e-01
#  32%|▎| 1900/6000 [1:12:06<2:06:13,  1.85s/it, B=2161, dG=4.350e-04, ep=66, eps=6.92
# [DP step 1900] B=2161 | Δ=4.350e-04 | noise_std=5.655e-04 | avg_grad_RMS=1.273e-03 | RMS/noise=2.252e+00
#  32%|▎| 1950/6000 [1:14:02<2:24:28,  2.14s/it, B=2081, dG=4.266e-04, ep=68, eps=7.02
# [DP step 1950] B=2081 | Δ=4.266e-04 | noise_std=5.545e-04 | avg_grad_RMS=1.112e-03 | RMS/noise=2.005e+00
#  33%|▎| 2000/6000 [1:15:45<1:56:17,  1.74s/it, B=2048, dG=5.115e-04, ep=69, eps=7.12
# [DP step 2000] B=2048 | Δ=5.115e-04 | noise_std=6.650e-04 | avg_grad_RMS=1.251e-03 | RMS/noise=1.881e+00
#  34%|▎| 2050/6000 [1:17:41<1:55:15,  1.75s/it, B=2027, dG=4.802e-04, ep=71, eps=7.22
# [DP step 2050] B=2027 | Δ=4.802e-04 | noise_std=6.243e-04 | avg_grad_RMS=1.409e-03 | RMS/noise=2.257e+00
#  35%|▎| 2100/6000 [1:19:38<1:58:36,  1.82s/it, B=2076, dG=4.602e-04, ep=73, eps=7.31
# [DP step 2100] B=2076 | Δ=4.602e-04 | noise_std=5.983e-04 | avg_grad_RMS=8.982e-04 | RMS/noise=1.501e+00
#  36%|▎| 2150/6000 [1:21:35<3:02:20,  2.84s/it, B=2123, dG=4.505e-04, ep=75, eps=7.41
# [DP step 2150] B=2123 | Δ=4.505e-04 | noise_std=5.857e-04 | avg_grad_RMS=1.059e-03 | RMS/noise=1.808e+00
#  37%|▎| 2200/6000 [1:23:17<1:52:22,  1.77s/it, B=2064, dG=4.495e-04, ep=76, eps=7.51
# [DP step 2200] B=2064 | Δ=4.495e-04 | noise_std=5.843e-04 | avg_grad_RMS=8.850e-04 | RMS/noise=1.514e+00
#  38%|▍| 2250/6000 [1:25:15<1:51:43,  1.79s/it, B=2081, dG=4.405e-04, ep=78, eps=7.60
# [DP step 2250] B=2081 | Δ=4.405e-04 | noise_std=5.727e-04 | avg_grad_RMS=9.592e-04 | RMS/noise=1.675e+00
#  38%|▍| 2300/6000 [1:27:12<2:00:52,  1.96s/it, B=2161, dG=4.453e-04, ep=80, eps=7.70
# [DP step 2300] B=2161 | Δ=4.453e-04 | noise_std=5.789e-04 | avg_grad_RMS=5.432e-04 | RMS/noise=9.382e-01
#  39%|▍| 2350/6000 [1:29:09<4:52:18,  4.81s/it, B=2049, dG=4.977e-04, ep=82, eps=7.79
# [DP step 2350] B=2049 | Δ=4.977e-04 | noise_std=6.470e-04 | avg_grad_RMS=1.809e-03 | RMS/noise=2.795e+00
#  40%|▍| 2400/6000 [1:30:50<1:46:10,  1.77s/it, B=1976, dG=5.140e-04, ep=83, eps=7.89
# [DP step 2400] B=1976 | Δ=5.140e-04 | noise_std=6.682e-04 | avg_grad_RMS=1.276e-03 | RMS/noise=1.909e+00
#  41%|▍| 2450/6000 [1:32:47<1:46:12,  1.80s/it, B=1969, dG=4.987e-04, ep=85, eps=7.98
# [DP step 2450] B=1969 | Δ=4.987e-04 | noise_std=6.483e-04 | avg_grad_RMS=1.182e-03 | RMS/noise=1.824e+00
#  42%|▍| 2500/6000 [1:34:44<2:11:49,  2.26s/it, B=2010, dG=5.072e-04, ep=87, eps=8.07
# [DP step 2500] B=2010 | Δ=5.072e-04 | noise_std=6.593e-04 | avg_grad_RMS=5.029e-04 | RMS/noise=7.627e-01
#  42%|▍| 2550/6000 [1:36:26<1:38:43,  1.72s/it, B=1993, dG=4.854e-04, ep=88, eps=8.16
# [DP step 2550] B=1993 | Δ=4.854e-04 | noise_std=6.310e-04 | avg_grad_RMS=2.010e-03 | RMS/noise=3.186e+00
#  43%|▍| 2600/6000 [1:38:23<1:39:40,  1.76s/it, B=1934, dG=4.940e-04, ep=90, eps=8.26
# [DP step 2600] B=1934 | Δ=4.940e-04 | noise_std=6.422e-04 | avg_grad_RMS=9.812e-04 | RMS/noise=1.528e+00
#  44%|▍| 2650/6000 [1:40:21<1:46:44,  1.91s/it, B=2124, dG=4.559e-04, ep=92, eps=8.34
# [DP step 2650] B=2124 | Δ=4.559e-04 | noise_std=5.926e-04 | avg_grad_RMS=8.333e-04 | RMS/noise=1.406e+00
#  45%|▍| 2700/6000 [1:42:18<3:00:00,  3.27s/it, B=2123, dG=4.600e-04, ep=94, eps=8.43
# [DP step 2700] B=2123 | Δ=4.600e-04 | noise_std=5.980e-04 | avg_grad_RMS=3.971e-04 | RMS/noise=6.641e-01
#  46%|▍| 2750/6000 [1:44:01<1:34:53,  1.75s/it, B=2008, dG=5.197e-04, ep=95, eps=8.52
# [DP step 2750] B=2008 | Δ=5.197e-04 | noise_std=6.756e-04 | avg_grad_RMS=1.303e-03 | RMS/noise=1.928e+00
#  47%|▍| 2800/6000 [1:45:58<1:37:42,  1.83s/it, B=2053, dG=4.680e-04, ep=97, eps=8.61
# [DP step 2800] B=2053 | Δ=4.680e-04 | noise_std=6.083e-04 | avg_grad_RMS=6.706e-04 | RMS/noise=1.102e+00
#  48%|▍| 2850/6000 [1:47:55<1:45:53,  2.02s/it, B=2049, dG=4.762e-04, ep=99, eps=8.70
# [DP step 2850] B=2049 | Δ=4.762e-04 | noise_std=6.190e-04 | avg_grad_RMS=5.062e-04 | RMS/noise=8.178e-01
#  48%|▍| 2899/6000 [1:49:38<1:30:42,  1.76s/it, B=2053, dG=4.859e-04, ep=100, eps=8.7
# [DP step 2900] B=2053 | Δ=4.859e-04 | noise_std=6.317e-04 | avg_grad_RMS=9.431e-04 | RMS/noise=1.493e+00
#  49%|▍| 2950/6000 [1:51:34<1:32:12,  1.81s/it, B=2027, dG=4.983e-04, ep=102, eps=8.8
# [DP step 2950] B=2027 | Δ=4.983e-04 | noise_std=6.478e-04 | avg_grad_RMS=1.783e-03 | RMS/noise=2.753e+00
#  50%|▌| 3000/6000 [1:53:31<1:29:29,  1.79s/it, B=2014, dG=4.773e-04, ep=104, eps=8.9
# [DP step 3000] B=2014 | Δ=4.773e-04 | noise_std=6.205e-04 | avg_grad_RMS=7.122e-04 | RMS/noise=1.148e+00
#  51%|▌| 3050/6000 [1:55:28<2:03:07,  2.50s/it, B=1983, dG=5.093e-04, ep=106, eps=9.0
# [DP step 3050] B=1983 | Δ=5.093e-04 | noise_std=6.621e-04 | avg_grad_RMS=1.168e-03 | RMS/noise=1.765e+00
#  52%|▌| 3100/6000 [1:57:10<1:25:32,  1.77s/it, B=2127, dG=4.330e-04, ep=107, eps=9.1
# [DP step 3100] B=2127 | Δ=4.330e-04 | noise_std=5.629e-04 | avg_grad_RMS=5.452e-04 | RMS/noise=9.685e-01
#  52%|▌| 3150/6000 [1:59:09<1:23:47,  1.76s/it, B=2024, dG=4.934e-04, ep=109, eps=9.2
# [DP step 3150] B=2024 | Δ=4.934e-04 | noise_std=6.415e-04 | avg_grad_RMS=5.421e-04 | RMS/noise=8.451e-01
#  53%|▌| 3200/6000 [2:01:07<1:30:16,  1.93s/it, B=2056, dG=4.711e-04, ep=111, eps=9.3
# [DP step 3200] B=2056 | Δ=4.711e-04 | noise_std=6.124e-04 | avg_grad_RMS=1.321e-03 | RMS/noise=2.158e+00
#  54%|▌| 3250/6000 [2:03:05<2:57:32,  3.87s/it, B=2006, dG=4.519e-04, ep=113, eps=9.3
# [DP step 3250] B=2006 | Δ=4.519e-04 | noise_std=5.875e-04 | avg_grad_RMS=1.689e-03 | RMS/noise=2.876e+00
#  55%|▌| 3300/6000 [2:04:48<1:20:05,  1.78s/it, B=2082, dG=4.618e-04, ep=114, eps=9.4
# [DP step 3300] B=2082 | Δ=4.618e-04 | noise_std=6.003e-04 | avg_grad_RMS=2.024e-03 | RMS/noise=3.372e+00
#  56%|▌| 3350/6000 [2:06:48<1:30:27,  2.05s/it, B=2050, dG=5.076e-04, ep=116, eps=9.5
# [DP step 3350] B=2050 | Δ=5.076e-04 | noise_std=6.599e-04 | avg_grad_RMS=2.022e-03 | RMS/noise=3.064e+00
#  57%|▌| 3400/6000 [2:08:44<1:30:24,  2.09s/it, B=2023, dG=4.892e-04, ep=118, eps=9.6
# [DP step 3400] B=2023 | Δ=4.892e-04 | noise_std=6.360e-04 | avg_grad_RMS=1.063e-03 | RMS/noise=1.671e+00
#  57%|▌| 3450/6000 [2:10:28<1:13:18,  1.72s/it, B=1926, dG=4.877e-04, ep=119, eps=9.7
# [DP step 3450] B=1926 | Δ=4.877e-04 | noise_std=6.340e-04 | avg_grad_RMS=8.120e-04 | RMS/noise=1.281e+00
#  58%|▌| 3500/6000 [2:12:26<1:14:22,  1.79s/it, B=2081, dG=4.585e-04, ep=121, eps=9.8
# [DP step 3500] B=2081 | Δ=4.585e-04 | noise_std=5.960e-04 | avg_grad_RMS=1.445e-03 | RMS/noise=2.424e+00
#  59%|▌| 3550/6000 [2:14:22<1:13:20,  1.80s/it, B=2063, dG=5.458e-04, ep=123, eps=9.8
# [DP step 3550] B=2063 | Δ=5.458e-04 | noise_std=7.095e-04 | avg_grad_RMS=1.082e-03 | RMS/noise=1.525e+00
#  60%|▌| 3600/6000 [2:16:19<1:51:37,  2.79s/it, B=2013, dG=4.776e-04, ep=125, eps=9.9
# [DP step 3600] B=2013 | Δ=4.776e-04 | noise_std=6.208e-04 | avg_grad_RMS=8.105e-04 | RMS/noise=1.305e+00
#  60%|▌| 3625/6000 [2:17:18<4:03:15,  6.15s/it, B=2013, dG=4.776e-04, ep=125, eps=9.9
# Stopping: epsilon reached 10.00 (>= 10.0) at step 3626
#  60%|▌| 3625/6000 [2:17:27<1:30:03,  2.28s/it, B=2013, dG=4.776e-04, ep=125, eps=9.9

# %% [markdown]
# ### Evaluation with EMA and live model

# %%
print("\n>>> Evaluating EMA Model (w=2.0)...")
metrics_ema_w2 = evaluate_trainer(
    trainer2, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=2.0, use_ema=True)
# Out:
# >>> Evaluating EMA Model (w=2.0)...
# --> Loading EMA weights for PT generation...
# Generate synth 60000 (EMA=True): 100%|████████████| 235/235 [35:01<00:00,  8.94s/it]
# --> Loading EMA weights for PNG export...
# Export PNGs (EMA=True): 100%|███████████████████████| 79/79 [11:53<00:00,  9.04s/it]
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: ema, w=2.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.7878
#
# [sklearn] DecisionTree...
#   test_acc: 0.6349
#
# [sklearn] RandomForest...
#   test_acc: 0.8164

# %%
print("\n>>> Evaluating EMA Model (w=0.0)...")
metrics_ema_w0 = evaluate_trainer(
    trainer2, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=0.0, use_ema=True)
# Out:
# >>> Evaluating EMA Model (w=0.0)...
# --> Loading EMA weights for PT generation...
# Generate synth 60000 (EMA=True): 100%|████████████| 235/235 [17:40<00:00,  4.51s/it]
# --> Loading EMA weights for PNG export...
# Export PNGs (EMA=True): 100%|███████████████████████| 79/79 [06:03<00:00,  4.61s/it]
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: ema, w=0.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.7032
#
# [sklearn] DecisionTree...
#   test_acc: 0.5149
#
# [sklearn] RandomForest...
#   test_acc: 0.8177

# %%
print("\n>>> Evaluating LIVE Model (w=2.0)...")
metrics_live_w2 = evaluate_trainer(
    trainer2, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=2.0, use_ema=False)
# Out:
# >>> Evaluating LIVE Model (w=2.0)...
# --> Using LIVE weights for PT generation...
# Generate synth 60000 (EMA=False): 100%|███████████| 235/235 [35:03<00:00,  8.95s/it]
# --> Using LIVE weights for PNG export...
# Export PNGs (EMA=False): 100%|██████████████████████| 79/79 [11:54<00:00,  9.04s/it]
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: live, w=2.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.803
#
# [sklearn] DecisionTree...
#   test_acc: 0.6156
#
# [sklearn] RandomForest...
#   test_acc: 0.814

# %%
print("\n>>> Evaluating LIVE Model (w=0.0)...")
metrics_live_w0 = evaluate_trainer(
    trainer2, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=0.0, use_ema=False)
# Out:
# >>> Evaluating LIVE Model (w=0.0)...
# --> Using LIVE weights for PT generation...
# Generate synth 60000 (EMA=False): 100%|███████████| 235/235 [17:43<00:00,  4.53s/it]
# --> Using LIVE weights for PNG export...
# Export PNGs (EMA=False): 100%|██████████████████████| 79/79 [06:04<00:00,  4.62s/it]
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: live, w=0.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.7155
#
# [sklearn] DecisionTree...
#   test_acc: 0.5496
#
# [sklearn] RandomForest...
#   test_acc: 0.8183

# %%
ddpm_cfg = DDPMConfig(timesteps=1000, beta_start=1e-4, beta_end=0.02)

N = len(mnist_train)
q = 2048 / N
steps = 10000
lr = 3e-4
K_MULT = 32
EMA_DECAY = 0.999

# DP settings
C_WEIGHT = 1.3
NOISE_MULT = 1.2
DELTA = 1e-5

X0_PUBLIC = 28.0        # sqrt(784) for MNIST in [-1,1]
Huber_R = 1.0

PI_ITERS = 2
CLIP_EVERY = 20

exp_name = (
    f"improved_eps10_DP_Diffusion_NoGradClip_publicBounds_q{q:.6f}_steps{steps}_K{K_MULT}"
    f"_C{C_WEIGHT}_nm{NOISE_MULT}_X0{X0_PUBLIC}_R{Huber_R}"
    f"_pi{PI_ITERS}_clipEvery{CLIP_EVERY}"
)

model = CondDiffUNet(
    n_classes=11,
    base_channels=32,
    use_lip_norm=False,
).to(device)

# %%
trainer3 = DiffusionDPTrainer(
    exp_name=exp_name,
    model=model,
    ddpm_cfg=ddpm_cfg,
    train_dataset=mnist_train,
    test_dataset=mnist_test,
    q_sample_rate=q,
    steps=steps,
    lr=lr,
    K_noise_mult=K_MULT,
    ema_decay=EMA_DECAY,
    C_weight=C_WEIGHT,
    noise_multiplier=NOISE_MULT,
    delta=DELTA,
    X0_public=X0_PUBLIC,
    Huber_R=Huber_R,
    pi_iters=PI_ITERS,
    clip_every=CLIP_EVERY,
)

trainer3.train(log_every=50)
# Out:
# [improved_eps10_DP_Diffusion_NoGradClip_publicBounds_q0.034133_steps10000_K32_C1.3_nm1.2_X028.0_R1.0_pi2_clipEvery20] Poisson sampling q=0.034133 | steps=10000 | ~29 steps/epoch
#   0%|                                           | 1/10000 [00:03<9:15:04,  3.33s/it]
# [DP step 1] B=2016 | Δ=9.586e-04 | noise_std=1.150e-03 | avg_grad_RMS=2.081e-02 | RMS/noise=1.809e+01
#   0%|                                           | 2/10000 [00:06<9:07:25,  3.29s/it]
# [DP step 2] B=2009 | Δ=9.620e-04 | noise_std=1.154e-03 | avg_grad_RMS=4.473e-03 | RMS/noise=3.875e+00
#   0%|                                           | 3/10000 [00:09<9:14:07,  3.33s/it]
# [DP step 3] B=2087 | Δ=9.260e-04 | noise_std=1.111e-03 | avg_grad_RMS=2.660e-03 | RMS/noise=2.394e+00
#   0%|                                           | 4/10000 [00:13<9:10:13,  3.30s/it]
# [DP step 4] B=2016 | Δ=9.586e-04 | noise_std=1.150e-03 | avg_grad_RMS=2.907e-03 | RMS/noise=2.527e+00
#   0%|                                          | 5/10000 [00:17<10:05:10,  3.63s/it]
# [DP step 5] B=2020 | Δ=9.567e-04 | noise_std=1.148e-03 | avg_grad_RMS=1.279e-03 | RMS/noise=1.114e+00
#   0%| | 50/10000 [03:17<10:20:44,  3.74s/it, B=2076, dG=9.511e-04, ep=2, eps=1.53, l
# [DP step 50] B=2076 | Δ=9.511e-04 | noise_std=1.141e-03 | avg_grad_RMS=4.248e-04 | RMS/noise=3.722e-01
#   1%| | 100/10000 [06:42<9:17:40,  3.38s/it, B=2029, dG=9.915e-04, ep=4, eps=1.91, l
# [DP step 100] B=2029 | Δ=9.915e-04 | noise_std=1.190e-03 | avg_grad_RMS=7.574e-04 | RMS/noise=6.366e-01
#   2%| | 150/10000 [10:15<11:56:26,  4.36s/it, B=2073, dG=9.728e-04, ep=6, eps=2.24,
# [DP step 150] B=2073 | Δ=9.728e-04 | noise_std=1.167e-03 | avg_grad_RMS=5.481e-04 | RMS/noise=4.695e-01
#   2%| | 200/10000 [13:32<9:34:04,  3.51s/it, B=2036, dG=9.992e-04, ep=7, eps=2.53, l
# [DP step 200] B=2036 | Δ=9.992e-04 | noise_std=1.199e-03 | avg_grad_RMS=3.688e-03 | RMS/noise=3.076e+00
#   2%| | 250/10000 [17:03<9:48:44,  3.62s/it, B=2051, dG=9.799e-04, ep=9, eps=2.80, l
# [DP step 250] B=2051 | Δ=9.799e-04 | noise_std=1.176e-03 | avg_grad_RMS=1.727e-03 | RMS/noise=1.468e+00
#   3%| | 300/10000 [20:29<9:43:23,  3.61s/it, B=2016, dG=1.002e-03, ep=11, eps=3.04,
# [DP step 300] B=2016 | Δ=1.002e-03 | noise_std=1.202e-03 | avg_grad_RMS=1.145e-03 | RMS/noise=9.518e-01
#   4%| | 350/10000 [23:55<15:18:48,  5.71s/it, B=2061, dG=1.006e-03, ep=13, eps=3.27,
# [DP step 350] B=2061 | Δ=1.006e-03 | noise_std=1.207e-03 | avg_grad_RMS=7.708e-04 | RMS/noise=6.386e-01
#   4%| | 400/10000 [27:03<9:29:24,  3.56s/it, B=1953, dG=1.062e-03, ep=14, eps=3.49,
# [DP step 400] B=1953 | Δ=1.062e-03 | noise_std=1.274e-03 | avg_grad_RMS=8.489e-04 | RMS/noise=6.663e-01
#   4%| | 450/10000 [30:22<9:02:10,  3.41s/it, B=2006, dG=1.015e-03, ep=16, eps=3.70,
# [DP step 450] B=2006 | Δ=1.015e-03 | noise_std=1.218e-03 | avg_grad_RMS=1.015e-03 | RMS/noise=8.329e-01
#   5%| | 500/10000 [33:43<10:14:03,  3.88s/it, B=2021, dG=9.746e-04, ep=18, eps=3.89,
# [DP step 500] B=2021 | Δ=9.746e-04 | noise_std=1.169e-03 | avg_grad_RMS=1.638e-03 | RMS/noise=1.400e+00
#   6%| | 550/10000 [36:49<9:00:42,  3.43s/it, B=2036, dG=1.069e-03, ep=19, eps=4.08,
# [DP step 550] B=2036 | Δ=1.069e-03 | noise_std=1.283e-03 | avg_grad_RMS=4.140e-04 | RMS/noise=3.228e-01
#   6%| | 600/10000 [40:10<8:54:08,  3.41s/it, B=2053, dG=1.055e-03, ep=21, eps=4.27,
# [DP step 600] B=2053 | Δ=1.055e-03 | noise_std=1.266e-03 | avg_grad_RMS=6.789e-04 | RMS/noise=5.363e-01
#   6%| | 650/10000 [43:29<8:58:57,  3.46s/it, B=2111, dG=1.061e-03, ep=23, eps=4.44,
# [DP step 650] B=2111 | Δ=1.061e-03 | noise_std=1.273e-03 | avg_grad_RMS=4.933e-04 | RMS/noise=3.876e-01
#   7%| | 700/10000 [46:52<11:32:29,  4.47s/it, B=2028, dG=1.044e-03, ep=25, eps=4.62,
# [DP step 700] B=2028 | Δ=1.044e-03 | noise_std=1.253e-03 | avg_grad_RMS=8.657e-04 | RMS/noise=6.909e-01
#   8%| | 750/10000 [49:57<9:23:55,  3.66s/it, B=1934, dG=1.138e-03, ep=26, eps=4.78,
# [DP step 750] B=1934 | Δ=1.138e-03 | noise_std=1.366e-03 | avg_grad_RMS=3.336e-04 | RMS/noise=2.443e-01
#   8%| | 800/10000 [53:16<8:40:14,  3.39s/it, B=2048, dG=1.099e-03, ep=28, eps=4.95,
# [DP step 800] B=2048 | Δ=1.099e-03 | noise_std=1.319e-03 | avg_grad_RMS=2.547e-04 | RMS/noise=1.931e-01
#   8%| | 850/10000 [56:35<8:57:12,  3.52s/it, B=2052, dG=1.010e-03, ep=30, eps=5.11,
# [DP step 850] B=2052 | Δ=1.010e-03 | noise_std=1.211e-03 | avg_grad_RMS=1.306e-03 | RMS/noise=1.078e+00
#   9%| | 900/10000 [59:53<16:19:10,  6.46s/it, B=2078, dG=1.060e-03, ep=32, eps=5.26,
# [DP step 900] B=2078 | Δ=1.060e-03 | noise_std=1.272e-03 | avg_grad_RMS=1.127e-03 | RMS/noise=8.855e-01
#  10%| | 950/10000 [1:02:58<8:30:52,  3.39s/it, B=2097, dG=1.087e-03, ep=33, eps=5.41
# [DP step 950] B=2097 | Δ=1.087e-03 | noise_std=1.305e-03 | avg_grad_RMS=9.590e-04 | RMS/noise=7.350e-01
#  10%| | 1000/10000 [1:06:17<8:47:56,  3.52s/it, B=2075, dG=1.140e-03, ep=35, eps=5.5
# [DP step 1000] B=2075 | Δ=1.140e-03 | noise_std=1.369e-03 | avg_grad_RMS=7.585e-04 | RMS/noise=5.542e-01
#  10%| | 1050/10000 [1:09:36<9:40:36,  3.89s/it, B=2075, dG=1.110e-03, ep=37, eps=5.7
# [DP step 1050] B=2075 | Δ=1.110e-03 | noise_std=1.332e-03 | avg_grad_RMS=1.785e-03 | RMS/noise=1.340e+00
#  11%| | 1100/10000 [1:12:40<8:31:17,  3.45s/it, B=2031, dG=1.126e-03, ep=38, eps=5.8
# [DP step 1100] B=2031 | Δ=1.126e-03 | noise_std=1.351e-03 | avg_grad_RMS=7.842e-04 | RMS/noise=5.803e-01
#  12%| | 1150/10000 [1:15:59<8:07:51,  3.31s/it, B=2054, dG=1.230e-03, ep=40, eps=5.9
# [DP step 1150] B=2054 | Δ=1.230e-03 | noise_std=1.476e-03 | avg_grad_RMS=4.520e-04 | RMS/noise=3.062e-01
#  12%| | 1200/10000 [1:19:16<8:26:27,  3.45s/it, B=2026, dG=1.173e-03, ep=42, eps=6.1
# [DP step 1200] B=2026 | Δ=1.173e-03 | noise_std=1.407e-03 | avg_grad_RMS=5.660e-04 | RMS/noise=4.022e-01
#  12%|▏| 1250/10000 [1:22:32<11:42:55,  4.82s/it, B=2071, dG=1.112e-03, ep=44, eps=6.
# [DP step 1250] B=2071 | Δ=1.112e-03 | noise_std=1.334e-03 | avg_grad_RMS=1.062e-03 | RMS/noise=7.959e-01
#  13%|▏| 1300/10000 [1:25:37<8:00:57,  3.32s/it, B=2078, dG=1.090e-03, ep=45, eps=6.4
# [DP step 1300] B=2078 | Δ=1.090e-03 | noise_std=1.308e-03 | avg_grad_RMS=5.611e-04 | RMS/noise=4.289e-01
#  14%|▏| 1350/10000 [1:28:52<8:00:08,  3.33s/it, B=2032, dG=1.176e-03, ep=47, eps=6.5
# [DP step 1350] B=2032 | Δ=1.176e-03 | noise_std=1.411e-03 | avg_grad_RMS=7.104e-04 | RMS/noise=5.034e-01
#  14%|▏| 1400/10000 [1:32:09<8:41:44,  3.64s/it, B=2093, dG=1.090e-03, ep=49, eps=6.6
# [DP step 1400] B=2093 | Δ=1.090e-03 | noise_std=1.308e-03 | avg_grad_RMS=4.024e-04 | RMS/noise=3.076e-01
#  14%|▏| 1449/10000 [1:35:11<7:48:21,  3.29s/it, B=2074, dG=1.114e-03, ep=50, eps=6.8
# [DP step 1450] B=2074 | Δ=1.114e-03 | noise_std=1.337e-03 | avg_grad_RMS=6.960e-04 | RMS/noise=5.205e-01
#  15%|▏| 1500/10000 [1:38:27<7:54:38,  3.35s/it, B=2006, dG=1.242e-03, ep=52, eps=6.9
# [DP step 1500] B=2006 | Δ=1.242e-03 | noise_std=1.491e-03 | avg_grad_RMS=9.922e-04 | RMS/noise=6.655e-01
#  16%|▏| 1550/10000 [1:41:46<8:00:02,  3.41s/it, B=2125, dG=1.195e-03, ep=54, eps=7.0
# [DP step 1550] B=2125 | Δ=1.195e-03 | noise_std=1.434e-03 | avg_grad_RMS=2.115e-04 | RMS/noise=1.475e-01
#  16%|▏| 1600/10000 [1:45:01<9:30:24,  4.07s/it, B=2052, dG=1.239e-03, ep=56, eps=7.1
# [DP step 1600] B=2052 | Δ=1.239e-03 | noise_std=1.487e-03 | avg_grad_RMS=1.076e-03 | RMS/noise=7.234e-01
#  16%|▏| 1650/10000 [1:48:04<7:48:59,  3.37s/it, B=2042, dG=1.282e-03, ep=57, eps=7.3
# [DP step 1650] B=2042 | Δ=1.282e-03 | noise_std=1.539e-03 | avg_grad_RMS=4.208e-04 | RMS/noise=2.734e-01
#  17%|▏| 1700/10000 [1:51:21<8:14:48,  3.58s/it, B=1983, dG=1.477e-03, ep=59, eps=7.4
# [DP step 1700] B=1983 | Δ=1.477e-03 | noise_std=1.773e-03 | avg_grad_RMS=2.690e-04 | RMS/noise=1.517e-01
#  18%|▏| 1750/10000 [1:54:39<7:59:08,  3.48s/it, B=2078, dG=1.296e-03, ep=61, eps=7.5
# [DP step 1750] B=2078 | Δ=1.296e-03 | noise_std=1.555e-03 | avg_grad_RMS=4.721e-04 | RMS/noise=3.036e-01
#  18%|▏| 1800/10000 [1:57:56<12:33:50,  5.52s/it, B=2070, dG=1.319e-03, ep=63, eps=7.
# [DP step 1800] B=2070 | Δ=1.319e-03 | noise_std=1.583e-03 | avg_grad_RMS=1.081e-03 | RMS/noise=6.832e-01
#  18%|▏| 1850/10000 [2:00:59<7:44:28,  3.42s/it, B=2066, dG=1.138e-03, ep=64, eps=7.7
# [DP step 1850] B=2066 | Δ=1.138e-03 | noise_std=1.365e-03 | avg_grad_RMS=7.038e-04 | RMS/noise=5.154e-01
#  19%|▏| 1900/10000 [2:04:17<7:42:58,  3.43s/it, B=2144, dG=1.180e-03, ep=66, eps=7.8
# [DP step 1900] B=2144 | Δ=1.180e-03 | noise_std=1.416e-03 | avg_grad_RMS=5.911e-04 | RMS/noise=4.174e-01
#  20%|▏| 1950/10000 [2:07:33<8:21:59,  3.74s/it, B=2058, dG=1.393e-03, ep=68, eps=8.0
# [DP step 1950] B=2058 | Δ=1.393e-03 | noise_std=1.672e-03 | avg_grad_RMS=9.131e-04 | RMS/noise=5.463e-01
#  20%|▏| 2000/10000 [2:10:35<7:34:15,  3.41s/it, B=2140, dG=1.316e-03, ep=69, eps=8.1
# [DP step 2000] B=2140 | Δ=1.316e-03 | noise_std=1.579e-03 | avg_grad_RMS=5.780e-04 | RMS/noise=3.660e-01
#  20%|▏| 2050/10000 [2:13:52<7:27:04,  3.37s/it, B=1975, dG=1.377e-03, ep=71, eps=8.2
# [DP step 2050] B=1975 | Δ=1.377e-03 | noise_std=1.653e-03 | avg_grad_RMS=2.007e-04 | RMS/noise=1.215e-01
#  21%|▏| 2100/10000 [2:17:10<7:26:41,  3.39s/it, B=2087, dG=1.334e-03, ep=73, eps=8.3
# [DP step 2100] B=2087 | Δ=1.334e-03 | noise_std=1.600e-03 | avg_grad_RMS=5.968e-04 | RMS/noise=3.729e-01
#  22%|▏| 2150/10000 [2:20:27<9:32:41,  4.38s/it, B=2027, dG=1.384e-03, ep=75, eps=8.4
# [DP step 2150] B=2027 | Δ=1.384e-03 | noise_std=1.661e-03 | avg_grad_RMS=3.643e-04 | RMS/noise=2.194e-01
#  22%|▏| 2200/10000 [2:23:28<7:15:38,  3.35s/it, B=2027, dG=1.681e-03, ep=76, eps=8.5
# [DP step 2200] B=2027 | Δ=1.681e-03 | noise_std=2.017e-03 | avg_grad_RMS=1.283e-03 | RMS/noise=6.360e-01
#  22%|▏| 2250/10000 [2:26:45<7:11:54,  3.34s/it, B=2041, dG=1.635e-03, ep=78, eps=8.6
# [DP step 2250] B=2041 | Δ=1.635e-03 | noise_std=1.962e-03 | avg_grad_RMS=4.595e-04 | RMS/noise=2.342e-01
#  23%|▏| 2300/10000 [2:30:03<7:32:56,  3.53s/it, B=2028, dG=1.574e-03, ep=80, eps=8.7
# [DP step 2300] B=2028 | Δ=1.574e-03 | noise_std=1.889e-03 | avg_grad_RMS=2.966e-04 | RMS/noise=1.570e-01
#  24%|▏| 2350/10000 [2:33:20<13:44:45,  6.47s/it, B=2117, dG=1.496e-03, ep=82, eps=8.
# [DP step 2350] B=2117 | Δ=1.496e-03 | noise_std=1.796e-03 | avg_grad_RMS=3.135e-04 | RMS/noise=1.746e-01
#  24%|▏| 2400/10000 [2:36:21<7:10:14,  3.40s/it, B=2114, dG=1.680e-03, ep=83, eps=9.0
# [DP step 2400] B=2114 | Δ=1.680e-03 | noise_std=2.016e-03 | avg_grad_RMS=6.592e-04 | RMS/noise=3.269e-01
#  24%|▏| 2450/10000 [2:39:37<7:04:21,  3.37s/it, B=2054, dG=1.734e-03, ep=85, eps=9.1
# [DP step 2450] B=2054 | Δ=1.734e-03 | noise_std=2.080e-03 | avg_grad_RMS=6.659e-04 | RMS/noise=3.201e-01
#  25%|▎| 2500/10000 [2:42:54<8:06:59,  3.90s/it, B=2097, dG=1.678e-03, ep=87, eps=9.2
# [DP step 2500] B=2097 | Δ=1.678e-03 | noise_std=2.014e-03 | avg_grad_RMS=4.734e-04 | RMS/noise=2.351e-01
#  26%|▎| 2550/10000 [2:45:57<6:56:06,  3.35s/it, B=2011, dG=1.614e-03, ep=88, eps=9.3
# [DP step 2550] B=2011 | Δ=1.614e-03 | noise_std=1.937e-03 | avg_grad_RMS=8.844e-04 | RMS/noise=4.565e-01
#  26%|▎| 2600/10000 [2:49:15<6:52:58,  3.35s/it, B=2023, dG=1.785e-03, ep=90, eps=9.4
# [DP step 2600] B=2023 | Δ=1.785e-03 | noise_std=2.142e-03 | avg_grad_RMS=6.103e-04 | RMS/noise=2.849e-01
#  26%|▎| 2650/10000 [2:52:31<7:01:05,  3.44s/it, B=2020, dG=1.726e-03, ep=92, eps=9.5
# [DP step 2650] B=2020 | Δ=1.726e-03 | noise_std=2.071e-03 | avg_grad_RMS=3.014e-04 | RMS/noise=1.455e-01
#  27%|▎| 2700/10000 [2:55:50<9:49:08,  4.84s/it, B=2108, dG=1.962e-03, ep=94, eps=9.6
# [DP step 2700] B=2108 | Δ=1.962e-03 | noise_std=2.355e-03 | avg_grad_RMS=2.633e-04 | RMS/noise=1.118e-01
#  28%|▎| 2750/10000 [2:58:52<6:40:39,  3.32s/it, B=2003, dG=2.047e-03, ep=95, eps=9.7
# [DP step 2750] B=2003 | Δ=2.047e-03 | noise_std=2.456e-03 | avg_grad_RMS=4.380e-04 | RMS/noise=1.783e-01
#  28%|▎| 2800/10000 [3:02:08<6:47:20,  3.39s/it, B=2121, dG=1.616e-03, ep=97, eps=9.8
# [DP step 2800] B=2121 | Δ=1.616e-03 | noise_std=1.939e-03 | avg_grad_RMS=1.746e-04 | RMS/noise=9.003e-02
#  28%|▎| 2850/10000 [3:05:26<7:10:40,  3.61s/it, B=2115, dG=1.761e-03, ep=99, eps=9.9
# [DP step 2850] B=2115 | Δ=1.761e-03 | noise_std=2.113e-03 | avg_grad_RMS=1.220e-04 | RMS/noise=5.772e-02
#  29%|▎| 2899/10000 [3:08:27<6:32:08,  3.31s/it, B=2092, dG=2.163e-03, ep=100, eps=10
# [DP step 2900] B=2092 | Δ=2.163e-03 | noise_std=2.596e-03 | avg_grad_RMS=2.119e-04 | RMS/noise=8.163e-02
#  30%|▎| 2950/10000 [3:11:42<6:33:44,  3.35s/it, B=2071, dG=2.159e-03, ep=102, eps=10
# [DP step 2950] B=2071 | Δ=2.159e-03 | noise_std=2.591e-03 | avg_grad_RMS=2.135e-04 | RMS/noise=8.242e-02
#  30%|▎| 3000/10000 [3:14:59<6:30:13,  3.34s/it, B=2022, dG=2.720e-03, ep=104, eps=10
# [DP step 3000] B=2022 | Δ=2.720e-03 | noise_std=3.264e-03 | avg_grad_RMS=8.642e-04 | RMS/noise=2.648e-01
#  30%|▎| 3050/10000 [3:18:15<7:51:16,  4.07s/it, B=2027, dG=2.623e-03, ep=106, eps=10
# [DP step 3050] B=2027 | Δ=2.623e-03 | noise_std=3.148e-03 | avg_grad_RMS=4.612e-04 | RMS/noise=1.465e-01
#  31%|▎| 3100/10000 [3:21:16<6:25:09,  3.35s/it, B=2071, dG=3.227e-03, ep=107, eps=10
# [DP step 3100] B=2071 | Δ=3.227e-03 | noise_std=3.873e-03 | avg_grad_RMS=2.294e-04 | RMS/noise=5.923e-02
#  31%|▎| 3134/10000 [3:23:38<10:22:22,  5.44s/it, B=2071, dG=3.227e-03, ep=107, eps=1
# Stopping: epsilon reached 10.50 (>= 10.5) at step 3135
#  31%|▎| 3134/10000 [3:23:49<7:26:32,  3.90s/it, B=2071, dG=3.227e-03, ep=107, eps=10

# %%
print("\n>>> Evaluating EMA Model (w=2.0)...")
metrics_ema_w2 = evaluate_trainer(
    trainer3, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=2.0, use_ema=True)
# Out:
# >>> Evaluating EMA Model (w=2.0)...
# --> Loading EMA weights for PT generation...
# Generate synth 60000 (EMA=True): 100%|████████████| 235/235 [35:05<00:00,  8.96s/it]
# --> Loading EMA weights for PNG export...
# Export PNGs (EMA=True): 100%|███████████████████████| 79/79 [11:54<00:00,  9.04s/it]
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: ema, w=2.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.8256
#
# [sklearn] DecisionTree...
#   test_acc: 0.604
#
# [sklearn] RandomForest...
#   test_acc: 0.7859

# %%
print("\n>>> Evaluating EMA Model (w=0.0)...")
metrics_ema_w0 = evaluate_trainer(
    trainer3, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=0.0, use_ema=True)
# Out:
# >>> Evaluating EMA Model (w=0.0)...
# --> Loading EMA weights for PT generation...
# Generate synth 60000 (EMA=True): 100%|████████████| 235/235 [17:41<00:00,  4.52s/it]
# --> Loading EMA weights for PNG export...
# Export PNGs (EMA=True): 100%|███████████████████████| 79/79 [06:04<00:00,  4.61s/it]
# /opt/conda/lib/python3.11/site-packages/torch_fidelity/metric_fid.py:47: DeprecationWarning: The `disp` argument is deprecated and will be removed in SciPy 1.18.0.
#   covmean, _ = scipy.linalg.sqrtm(sigma1.dot(sigma2), disp=False)
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: ema, w=0.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.7846
#
# [sklearn] DecisionTree...
#   test_acc: 0.5403
#
# [sklearn] RandomForest...
#   test_acc: 0.7959

# %%
print("\n>>> Evaluating LIVE Model (w=2.0)...")
metrics_live_w2 = evaluate_trainer(
    trainer3, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=2.0, use_ema=False)
# Out:
# >>> Evaluating LIVE Model (w=2.0)...
# --> Using LIVE weights for PT generation...
# Generate synth 60000 (EMA=False): 100%|███████████| 235/235 [35:05<00:00,  8.96s/it]
# --> Using LIVE weights for PNG export...
# Export PNGs (EMA=False): 100%|██████████████████████| 79/79 [11:53<00:00,  9.03s/it]
# /opt/conda/lib/python3.11/site-packages/torch_fidelity/metric_fid.py:47: DeprecationWarning: The `disp` argument is deprecated and will be removed in SciPy 1.18.0.
#   covmean, _ = scipy.linalg.sqrtm(sigma1.dot(sigma2), disp=False)
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: live, w=2.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.8135
#
# [sklearn] DecisionTree...
#   test_acc: 0.696
#
# [sklearn] RandomForest...
#   test_acc: 0.8247

# %%
print("\n>>> Evaluating LIVE Model (w=0.0)...")
metrics_live_w0 = evaluate_trainer(
    trainer3, mnist_train, mnist_test, fid_is_n=20000, synth_n=60000,
    guidance_scale=0.0, use_ema=False)
# Out:
# >>> Evaluating LIVE Model (w=0.0)...
# --> Using LIVE weights for PT generation...
# Generate synth 60000 (EMA=False): 100%|███████████| 235/235 [17:41<00:00,  4.52s/it]
# --> Using LIVE weights for PNG export...
# Export PNGs (EMA=False): 100%|██████████████████████| 79/79 [06:04<00:00,  4.61s/it]
# /opt/conda/lib/python3.11/site-packages/torch_fidelity/metric_fid.py:47: DeprecationWarning: The `disp` argument is deprecated and will be removed in SciPy 1.18.0.
#   covmean, _ = scipy.linalg.sqrtm(sigma1.dot(sigma2), disp=False)
# /tmp/ipykernel_41069/292187558.py:943: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(pt_path, map_location="cpu")
# --- Running Downstream Evaluation (Model: live, w=0.0) ---
# Loading data for sklearn eval...
# /tmp/ipykernel_41069/3928588880.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   d = torch.load(synth_pt_path, map_location="cpu")
# [sklearn] LogisticRegression...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   test_acc: 0.8345
#
# [sklearn] DecisionTree...
#   test_acc: 0.7077
#
# [sklearn] RandomForest...
#   test_acc: 0.8675
